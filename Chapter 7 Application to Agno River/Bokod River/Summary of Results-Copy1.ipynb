# %%
from scipy.sparse import diags #linalg
from scipy.linalg import solve
import numpy as np
from numpy.linalg import inv, det
from matplotlib import pyplot as plt

# %%
from matplotlib import animation as animation
from IPython.display import HTML

# %%
fig, ax = plt.subplots()
ax.grid(which='major', color='#DDDDDD', linewidth=1)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()
xmonth = ["Jan20", "Feb20", "Jun20", "Jul20", "Aug20", "Sep20", "Oct20", "Nov20", "Dec20", "Jan21", "Feb21", "Mar21",\
          "Apr21", "May21", "Jun21","Jul21", "Feb22", "Mar22"]
yactual = [10.1, 10.22, 9.01, 8.3, 8.82, 8.68, 9.47, 13.36, 9.28, 10.14, 8.62, 9, 8.31, 6.6, 6.62, 6.75, 7.4, 8.9]
ysimul = [10.420169328345938, 8.546755214461482, 9.148056453251725, 8.655026526671794, 9.635808564093214,\
          9.422345406127235, 10.779700470752509, 13.829555203917838, 9.85068991691308, 10.330056294444667,\
          8.895683380053807, 9.223017699859696, 8.71920142455382, 7.108769552174484, 7.735227605666792,\
          7.156497589010768, 7.963930348074147,8.879349412111731]
plt.plot(xmonth, yactual, 'ro--')
plt.plot(xmonth, ysimul , 'bs--')
plt.xticks(xmonth, xmonth, rotation='vertical')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("DO($mg/L$)")
plt.title("")
plt.savefig('DO Simulation.png', bbox_inches='tight') 

plt.show()

# %%
fig, ax = plt.subplots()
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()
xmonth = ["Jan20", "Feb20", "Jun20", "Jul20", "Aug20", "Sep20", "Oct20", "Nov20", "Dec20", "Jan21", "Feb21", "Mar21",\
          "Apr21", "May21", "Jun21","Jul21", "Feb22", "Mar22"]
yactual = [1, 1, 0.5, 1, 1, 1, 1, 0.5, 1, 0.5, 0.5, 1, 1, 1, 1, 1, 0.5, 2]
ysimul = [1.0477016437398896, 0.5488268794203894, 3.0182246434674447, 3.0182246434674447, 1.0477016437398896,\
          1.0477016437398896, 1.0475861901957273, 1.0226101326452854, 1.0477016437398896, 0.5238508218699448,\
          0.5488268794203894, 1.0477016437398896, 1.0477016437398896, 1.0227255861894473, 1.0227255861894473,\
          1.0477016437398896, 1.0477016437398896, 1.0477016437398896]
plt.plot(xmonth, yactual, 'ro--')
plt.plot(xmonth, ysimul, 'bs--')
plt.xticks(xmonth, xmonth, rotation='vertical')
plt.legend(["actual","simulated"], loc ="upper right")
plt.xlabel("Month")
plt.ylabel("BOD($mg/L$)")
plt.title("")
plt.savefig('BOD Simulation.png', bbox_inches='tight') 
plt.show()

# %%
fig, ax = plt.subplots()
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()
xmonth = ["Jan20", "Feb20", "Jun20", "Jul20", "Aug20", "Sep20", "Oct20", "Nov20", "Dec20", "Jan21", "Feb21", "Mar21",\
          "Apr21", "May21", "Jun21","Jul21", "Feb22", "Mar22"]
Temp = [23.33, 23.45, 25.49, 26.71, 24.41, 23.5, 20.59, 21.52, 21.26, 18.73, 22.79, 24, 25.61, 27.26, 25.48, 27.38, 22.18, 23.98]
plt.plot(xmonth, Temp, 'o--')
plt.legend(["Temp"], loc ="upper left")
plt.xticks(xmonth, xmonth, rotation='vertical')
plt.xlabel("Month")
plt.ylabel("Temperature $^{\circ}C$")
plt.title("")
plt.savefig('Water temperature at Bokod River.png', bbox_inches='tight') 
plt.show()
