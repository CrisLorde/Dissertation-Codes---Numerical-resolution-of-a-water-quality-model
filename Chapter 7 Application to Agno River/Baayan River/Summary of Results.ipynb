# %%
from scipy.sparse import diags #linalg
from scipy.linalg import solve
import numpy as np
from numpy.linalg import inv, det
from matplotlib import pyplot as plt

# %%
from matplotlib import animation as animation
from IPython.display import HTML

# %%
fig, ax = plt.subplots()
ax.grid(which='major', color='#DDDDDD', linewidth=1)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()
xmonth = ["Jan20", "Feb20", "Jun20", "Jul20", "Aug20", "Sep20", "Oct20", "Nov20", "Dec20", "Jan21", "Feb21", "Mar21",\
          "Apr21", "May21", "Jun21","Jul21", "Feb22", "Mar22"]
yactual = [10.02, 8.53, 8.84, 8.76, 8.89, 7.88, 9.04, 12.37, 9.42, 9.19, 8.2, 8.94, 8, 6.52, 6.83, 6.8, 6.42, 7.47]
ysimul = [10.64238141907844, 9.793852988203012, 9.12649881752253, 9.797315924763883, 9.473926924554549, 8.936349067727045,\
        9.6122459577644, 13.363248880379647, 9.63459989969996, 9.359992372128932, 8.963286581167054, 8.53218764411333,\
        8.039769848661365, 7.413059578736761, 6.824536270152003, 7.2926004142885805, 9.573077320339372, 8.298568422538048]
plt.plot(xmonth, yactual, 'ro--')
plt.plot(xmonth, ysimul , 'bs--')
plt.xticks(xmonth, xmonth, rotation='vertical')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("DO($mg/L$)")
plt.title("")
plt.savefig('DO Simulation Baayan.png', bbox_inches='tight') 

plt.show()

# %%
fig, ax = plt.subplots()
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()
xmonth = ["Jan20", "Feb20", "Jun20", "Jul20", "Aug20", "Sep20", "Oct20", "Nov20", "Dec20", "Jan21", "Feb21", "Mar21",\
          "Apr21", "May21", "Jun21","Jul21", "Feb22", "Mar22"]
yactual = [2, 1, 2, 1, 1, 1, 1, 1, 0.5, 1, 1, 1, 1, 1, 0.5, 1, 1, 0.5]
ysimul = [2.0189687035180213, 1.0260099216218812, 0.5130049608109406, 1.0260099216218812, 1.0260099216218812, \
          1.0260099216218812, 0.5295305306738117, 1.0260099216218812, 1.0260099216218812, 1.0094843517590106,\
          0.5295305306738117, 1.0260099216218812, 1.0260099216218812, 1.0094843517590106, 1.0260099216218812,\
          1.0260099216218812, 1.0260099216218812, 1.0260099216218812]
plt.plot(xmonth, yactual, 'ro--')
plt.plot(xmonth, ysimul, 'bs--')
plt.xticks(xmonth, xmonth, rotation='vertical')
plt.legend(["actual","simulated"], loc ="upper right")
plt.xlabel("Month")
plt.ylabel("BOD($mg/L$)")
plt.title("")
plt.savefig('BOD Simulation Baayan.png', bbox_inches='tight') 

plt.show()

# %%
fig, ax = plt.subplots()
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()
xmonth = ["Jan20", "Feb20", "Jun20", "Jul20", "Aug20", "Sep20", "Oct20", "Nov20", "Dec20", "Jan21", "Feb21", "Mar21",\
          "Apr21", "May21", "Jun21","Jul21", "Feb22", "Mar22"]
Temp = [19.86, 19.48, 23.63, 23.37, 20.84, 23.52, 19.16, 21.45, 20.40, 19.71, 20.29, 22.24, 23.49, 23.86, 22.88, 24.52,\
        21.64, 23.37, ]
plt.plot(xmonth, Temp, 'o--')
plt.legend(["Temp"], loc ="upper left")
plt.xticks(xmonth, xmonth, rotation='vertical')
plt.xlabel("Month")
plt.ylabel("Temperature $^{\circ}C$")
plt.title("")
plt.savefig('Temperature Baayan.png') 

plt.show()
