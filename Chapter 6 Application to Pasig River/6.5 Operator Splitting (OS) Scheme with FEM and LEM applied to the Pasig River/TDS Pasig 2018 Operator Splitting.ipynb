# %%
from scipy.sparse import diags #linalg
from scipy.linalg import solve
import numpy as np
from numpy.linalg import inv, det
from matplotlib import pyplot as plt

# %%
a1 = 0 
b1 = 7200
c1 = 2*b1
d1 = 3*b1
e1 = 4*b1
f1 = 5*b1
g1 = 6*b1
h1 = 7*b1
i1 = 8*b1
j1 = 9*b1
k1 = 10*b1
l1 = 11*b1
m1 = 12*b1
n1 = 13*b1
o1 = 14*b1
p1 = 15*b1
q1 = 16*b1
r1 = 17*b1

z = 0.01

# %%
#Depth per month of the sources
J1 = 3.93
J2 = 3.93
J3 = 0.73
J4 = 0.63
J5 = 0.8
J6 = 0.9

F1 = 4.03
F2 = 3.57
F3 = 0.53
F4 = 0.6
F5 = 1.17
F6 = 0.8

Mar1 = 3.83
Mar2 = 3.53 
Mar3 = 1.07
Mar4 = 0.37
Mar5 = 1.23
Mar6 = 0.67

Ap1 = 4.03
Ap2 = 3.97
Ap3 = 0.77
Ap4 = 0.53
Ap5 = 0.9
Ap6 = 0.57

Ma1 = 4.43
Ma2 = 3.4
Ma3 = 0.63
Ma4 = 0.9
Ma5 = 1.03
Ma6 = 0.63

Jun1 = 3.75
Jun2 = 3.8
Jun3 = 1.4
Jun4 = 0.7
Jun5 = 1.67
Jun6 = 1.03

Jul1 = 4.27
Jul2 = 4.23
Jul3 = 1.1
Jul4 = 1.15
Jul5 = 1.17
Jul6 = 1.2

Au1 = 4.03
Au2 = 4.53
Au3 = 1.73
Au4 = 1.03
Au5 = 1.3
Au6 = 1.73

S1 = 3.43
S2 = 3.9
S3 = 1.5
S4 = 0.77
S5 = 1.67
S6 = 1.73

O1 = 3.97
O2 = 3.6
O3 = 0.87
O4 = 0.6
O5 = 1.5
O6 = 0.77

N1 = 3.05
N2 = 3.3
N3 = 0.77
N4 = 0.47
N5 = 0.97
N6 = 0.8

D1 = 2.87
D2 = 2.43
D3 = 0.67
D4 = 0.43
D5 = 1.43
D6 = 0.8

# %%
#Wetted Perimeter
PJ1 = 2*J1 + 65
PJ2 = 2*J2 + 53
PJ3 = 2*J3 + 7
PJ4 = 2*J4 + 7
PJ5 = 2*J5 + 9
PJ6 = 2*J6 + 7

PF1 = 2*F1 + 65
PF2 = 2*F2 + 53
PF3 = 2*F3 + 7
PF4 = 2*F4 + 7
PF5 = 2*F5 + 9
PF6 = 2*F6 + 7

PMar1 = 2*Mar1 +  65
PMar2 = 2*Mar2 +  53
PMar3 = 2*Mar3 +  7
PMar4 = 2*Mar4 +  7
PMar5 = 2*Mar5 +  9
PMar6 = 2*Mar6 +  7

PAp1 = 2*Ap1 + 65
PAp2 = 2*Ap2 + 53
PAp3 = 2*Ap3 + 7
PAp4 = 2*Ap4 + 7
PAp5 = 2*Ap5 + 9
PAp6 = 2*Ap6 + 7

PMa1 = 2*Ma1 + 65
PMa2 = 2*Ma2 + 53
PMa3 = 2*Ma3 + 7
PMa4 = 2*Ma4 + 7
PMa5 = 2*Ma5 + 9
PMa6 = 2*Ma6 + 7

PJun1 = 2*Jun1 + 65
PJun2 = 2*Jun2 + 53
PJun3 = 2*Jun3 + 7
PJun4 = 2*Jun4 + 7
PJun5 = 2*Jun5 + 9
PJun6 = 2*Jun6 + 7

PJul1 = 2*Jul1 + 65
PJul2 = 2*Jul2 + 53
PJul3 = 2*Jul3 + 7
PJul4 = 2*Jul4 + 7
PJul5 = 2*Jul5 + 9
PJul6 = 2*Jul6 + 7

PAu1 = 2*Au1 + 65
PAu2 = 2*Au2 + 53
PAu3 = 2*Au3 + 7
PAu4 = 2*Au4 + 7
PAu5 = 2*Au5 + 9
PAu6 = 2*Au6 + 7

PS1 = 2*S1 + 65
PS2 = 2*S2 + 53
PS3 = 2*S3 + 7
PS4 = 2*S4 + 7
PS5 = 2*S5 + 9
PS6 = 2*S6 + 7

PO1 = 2*O1 + 65
PO2 = 2*O2 + 53
PO3 = 2*O3 + 7
PO4 = 2*O4 + 7
PO5 = 2*O5 + 9
PO6 = 2*O6 + 7

PN1 = 2*N1 + 65
PN2 = 2*N2 + 53
PN3 = 2*N3 + 7
PN4 = 2*N4 + 7
PN5 = 2*N5 + 9
PN6 = 2*N6 + 7

PD1 = 2*D1 + 65
PD2 = 2*D2 + 53
PD3 = 2*D3 + 7
PD4 = 2*D4 + 7
PD5 = 2*D5 + 9
PD6 = 2*D6 + 7

# %%
#depth and wetted perimeter of Guadalope and Lambingan
DepthBamGuadJ = 3.92
DepthBamGuadF = 3.48
DepthBamGuadMar = 3.55
DepthBamGuadAp = 3.98
DepthBamGuadMa = 3.73
DepthBamGuadJun = 3.39
DepthBamGuadJul = 3.74
DepthBamGuadAu = 3.6
DepthBamGuadS = 3.28
DepthBamGuadO = 2.85
DepthBamGuadN = 3.14
DepthBamGuadD = 2.52


DepthGuadJ = 3.9
DepthGuadF = 2.93
DepthGuadMar = 3.27
DepthGuadAp = 3.93
DepthGuadMa = 3.03
DepthGuadJun = 3.03
DepthGuadJul = 3.2
DepthGuadAu = 3.17
DepthGuadS = 3.13
DepthGuadO = 1.73
DepthGuadN = 3.23
DepthGuadD = 2.17

DepthGuadLamJ = 3.40
DepthGuadLamF = 3.27
DepthGuadLamMar = 3.55
DepthGuadLamAp = 4.18
DepthGuadLamMa = 3.42
DepthGuadLamJun = 3.57
DepthGuadLamJul = 3.92
DepthGuadLamAu = 3.27
DepthGuadLamS = 3.10
DepthGuadLamO = 1.78
DepthGuadLamN = 3.22
DepthGuadLamD = 2.82

DepthLamJ = 2.9
DepthLamF = 3.6
DepthLamMar = 3.83
DepthLamAp = 4.43 
DepthLamMa = 3.8
DepthLamJun = 4.1
DepthLamJul = 4.63
DepthLamAu = 3.37
DepthLamS = 3.07
DepthLamO = 1.83
DepthLamN = 3.2
DepthLamD = 3.47

PeriBamGuadJ = 2*DepthBamGuadJ + 70
PeriBamGuadF = 2*DepthBamGuadF + 70
PeriBamGuadMar = 2*DepthBamGuadMar + 70
PeriBamGuadAp = 2*DepthBamGuadAp + 70
PeriBamGuadMa = 2*DepthBamGuadMa + 70
PeriBamGuadJun = 2*DepthBamGuadJun + 70
PeriBamGuadJul = 2*DepthBamGuadJul + 70
PeriBamGuadAu = 2*DepthBamGuadAu + 70
PeriBamGuadS = 2*DepthBamGuadS + 70
PeriBamGuadO = 2*DepthBamGuadO + 70
PeriBamGuadN = 2*DepthBamGuadN + 70
PeriBamGuadD = 2*DepthBamGuadD + 70

PeriGuadJ = 2*DepthGuadJ + 76
PeriGuadF =  2*DepthGuadF + 76
PeriGuadMar =  2*DepthGuadMar + 76
PeriGuadAp =  2*DepthGuadAp + 76
PeriGuadMa =  2*DepthGuadMa + 76
PeriGuadJun =  2*DepthGuadJun + 76
PeriGuadJul =  2*DepthGuadJul + 76
PeriGuadAu =  2*DepthGuadAu + 76
PeriGuadS =  2*DepthGuadS + 76
PeriGuadO =  2*DepthGuadO + 76
PeriGuadN =  2*DepthGuadN + 76
PeriGuadD =  2*DepthGuadD + 76

PeriGuadLamJ = 2*DepthGuadLamJ + 80
PeriGuadLamF = 2*DepthGuadLamF + 80
PeriGuadLamMar = 2*DepthGuadLamMar + 80
PeriGuadLamAp = 2*DepthGuadLamAp + 80
PeriGuadLamMa = 2*DepthGuadLamMa + 80
PeriGuadLamJun = 2*DepthGuadLamJun + 80
PeriGuadLamJul = 2*DepthGuadLamJul + 80
PeriGuadLamAu = 2*DepthGuadLamAu + 80
PeriGuadLamS = 2*DepthGuadLamS + 80
PeriGuadLamO = 2*DepthGuadLamO + 80
PeriGuadLamN = 2*DepthGuadLamN + 80
PeriGuadLamD = 2*DepthGuadLamD + 80

PeriLamJ = 2*DepthLamJ + 85
PeriLamF = 2*DepthLamF + 85
PeriLamMar = 2*DepthLamMar + 85
PeriLamAp = 2*DepthLamAp + 85
PeriLamMa = 2*DepthLamMa + 85
PeriLamJun = 2*DepthLamJun + 85
PeriLamJul = 2*DepthLamJul + 85
PeriLamAu = 2*DepthLamAu + 85
PeriLamS = 2*DepthLamS + 85
PeriLamO = 2*DepthLamO + 85
PeriLamN = 2*DepthLamN + 85
PeriLamD = 2*DepthLamD + 85

hb = 1

# %%
def solver(T,dt,L1, L2, Z):
    N = int(round(T/dt))
    t = np.linspace(0,T,N+1) #time discrete
    M = int(round(L/dx))
    x = np.linspace(0,L,M+1) #space discrete
    E = np.zeros((M+1,N+1))
    S = np.zeros((M+1,N+1))
    C = np.zeros((M+1,N+1))
    PPX = np.zeros((M+1))
    Em = np.zeros((M+1,N+1))
    BM = np.zeros((M+1,12))
    Bi = np.zeros((M+1))
    RHS = np.zeros((M+1))
    B = np.zeros((M+1))
    A = np.zeros((M+1))
    QW = np.zeros((M+1,12))
    
    #initial conditions
    S[0,a1:b1] = 0.27
    S[0,b1:c1] = 0.33
    S[0,c1:d1] = 0.32
    S[0,d1:e1] = 0.37
    S[0,e1:f1] = 9.13
    S[0,f1:g1] = 0.53
    S[0,g1:h1] = 0.32
    S[0,h1:i1] = 0.34
    S[0,i1:j1] = 0.32
    S[0,j1:k1] = 0.26
    S[0,k1:l1] = 0.26
    S[0,l1:m1] = 0.27
    C[0,a1:b1] = z*S[0,a1:b1]
    C[0,b1:c1] = z*S[0,b1:c1]
    C[0,c1:d1] = z*S[0,c1:d1]
    C[0,d1:e1] = z*S[0,d1:e1]
    C[0,e1:f1] = z*S[0,e1:f1]
    C[0,f1:g1] = z*S[0,f1:g1]
    C[0,g1:h1] = z*S[0,g1:h1]
    C[0,h1:i1] = z*S[0,h1:i1]
    C[0,i1:j1] = z*S[0,i1:j1]
    C[0,j1:k1] = z*S[0,j1:k1]
    C[0,k1:l1] = z*S[0,k1:l1]
    C[0,l1:m1] = z*S[0,l1:m1]
    E[0,a1:b1] = PJ1*den*hb*S[0,a1:b1]#+PJ1*den*J1*theta*C[0,a1:b1]
    E[0,b1:c1] = PF1*den*hb*S[0,b1:c1]#+PF1*den*F1*theta*C[0,b1:c1]
    E[0,c1:d1] = PMar1*den*hb*S[0,c1:d1]#+PMar1*den*Mar1*theta*C[0,c1:d1]
    E[0,d1:e1] = PAp1*den*hb*S[0,d1:e1]#+PAp1*den*Ap1*theta*C[0,d1:e1]
    E[0,e1:f1] = PMa1*den*hb*S[0,e1:f1]#+PMa1*den*Ma1*theta*C[0,e1:f1]
    E[0,f1:g1] = PJun1*den*hb*S[0,f1:g1]#+PJun1*den*Jun1*theta*C[0,f1:g1]
    E[0,g1:h1] = PJul1*den*hb*S[0,g1:h1]#+PJul1*den*Jul1*theta*C[0,g1:h1]
    E[0,h1:i1] = PAu1*den*hb*S[0,h1:i1]#+PAu1*den*Au1*theta*C[0,h1:i1]
    E[0,i1:j1] = PS1*den*hb*S[0,i1:j1]#+PS1*den*S1*theta*C[0,i1:j1]
    E[0,j1:k1] = PO1*den*hb*S[0,j1:k1]#+PO1*den*O1*theta*C[0,j1:k1]
    E[0,k1:l1] = PN1*den*hb*S[0,k1:l1]#+PN1*den*N1*theta*C[0,k1:l1]
    E[0,l1:m1] = PD1*den*hb*S[0,l1:m1]#+PD1*den*D1*theta*C[0,l1:m1]
    
    #Flow Rate Boundary
    QW[0,0] = 151
    QW[24,0] = 18
    QW[66,0] = 2.04
    QW[72,0] = 0
    QW[88,0] = 0.65
    QW[148,0] = 0.88
    
    QW[0,1] = 71
    QW[24,1] = 15
    QW[66,1] = 1.04
    QW[72,1] = 0.63
    QW[88,1] = 0.95
    QW[148,1] = 1.68
    
    QW[0,2] = 117
    QW[24,2] = 35
    QW[66,2] = 1.42
    QW[72,2] = 0.54
    QW[88,2] = 1.33
    QW[148,2] = 0.94
    
    QW[0,3] = 60
    QW[24,3] = 0
    QW[66,3] = 1.19
    QW[72,3] = 0.63
    QW[88,3] = 1.13
    QW[148,3] = 0.64
    
    QW[0,4] = 184
    QW[24,4] = 19
    QW[66,4] = 0.79
    QW[72,4] = 1.32
    QW[88,4] = 2.04
    QW[148,4] = 0.93
    
    QW[0,5] = 88
    QW[24,5] = 74
    QW[66,5] = 3.53
    QW[72,5] = 0.83
    QW[88,5] = 2.25
    QW[148,5] = 1.01
    
    QW[0,6] = 286
    QW[24,6] = 69
    QW[66,6] = 3.85
    QW[72,6] = 1.13
    QW[88,6] = 1.37
    QW[148,6] = 1.85
    
    QW[0,7] = 63
    QW[24,7] = 48
    QW[66,7] = 3.15
    QW[72,7] = 0.87
    QW[88,7] = 1.52
    QW[148,7] = 1.57
    
    QW[0,8] = 80
    QW[24,8] = 39
    QW[66,8] = 2
    QW[72,8] = 0.54
    QW[88,8] = 1.50
    QW[148,8] = 3.03
    
    QW[0,9] = 323
    QW[24,9] = 30
    QW[66,9] = 1.28
    QW[72,9] = 0.42
    QW[88,9] = 6.21
    QW[148,9] = 1.02
    
    QW[0,10] = 214
    QW[24,10] = 10
    QW[66,10] = 1.08
    QW[72,10] = 0.20
    QW[88,10] = 1.05
    QW[148,10] = 1.01
    
    QW[0,11] = 125
    QW[24,11] = 2.58
    QW[66,11] = 1.83
    QW[72,11] = 0.12
    QW[88,11] = 0.26
    QW[148,11] = 0.50
   
    #boundary/sources
    BM[0,0] = QW[0,0]*(PJ1*den*hb*0.27) 
    BM[24,0] = QW[24,0]*(PJ2*den*J2*0.30)#+z*PJ2*J2*den*theta*0.30)
    BM[66,0] = QW[66,0]*(PJ3*den*J3*0.44)#+z*PJ3*J3*den*theta*0.44)
    BM[72,0] = QW[72,0]*(PJ4*den*J4*0.44)#+z*PJ4*J4*den*theta*0.44)
    BM[88,0] = QW[88,0]*(PJ5*den*J5*0.41)#+z*PJ5*J5*den*theta*0.41)
    BM[148,0] = QW[148,0]*(PJ6*den*J6*0.38)#+z*PJ6*J6*den*theta*0.38)
    
    BM[0,1] = QW[0,1]*(PF1*den*hb*S[0,b1])  
    BM[24,1] = QW[24,1]*(PF2*den*F2*0.41+z*PF2*F2*den*theta*0.41)
    BM[66,1] = QW[66,1]*(PF3*den*F3*0.44+z*PF3*F3*den*theta*0.44)
    BM[72,1] = QW[72,1]*(PF4*den*F4*0.51+z*PF4*F4*den*theta*0.51)
    BM[88,1] = QW[88,1]*(PF5*den*F5*0.49+z*PF5*F5*den*theta*0.49)
    BM[148,1] = QW[148,1]*(PF6*den*F6*0.47+z*PF6*F6*den*theta*0.47)
    
    BM[0,2] = QW[0,2]*(PMar1*den*hb*S[0,c1])  
    BM[24,2] = QW[24,2]*(PMar2*den*Mar2*0.43+z*PMar2*den*Mar2*theta*0.43)
    BM[66,2] = QW[66,2]*(PMar3*den*Mar3*0.41+z*PMar3*den*Mar3*theta*0.41)
    BM[72,2] = QW[72,2]*(PMar4*den*Mar4*0.48+z*PMar4*den*Mar4*theta*0.48)
    BM[88,2] = QW[88,2]*(PMar5*den*Mar5*0.48+z*PMar5*den*Mar5*theta*0.48)
    BM[148,2] = QW[148,2]*(PMar6*den*Mar6*0.57+z*PMar6*den*Mar6*theta*0.57)
    
    BM[0,3] = QW[0,3]*E[0,e1-1]  
    BM[24,3] = QW[24,3]*(PAp2*den*Ap2*0.43+z*PAp2*den*Ap2*theta*0.43)
    BM[66,3] = QW[66,3]*(PAp3*den*Ap3*0.40+z*PAp3*den*Ap3*theta*0.40)
    BM[72,3] = QW[72,3]*(PAp4*den*Ap4*0.52+z*PAp4*den*Ap4*theta*0.52)
    BM[88,3] = QW[88,3]*(PAp5*den*Ap5*0.51+z*PAp5*den*Ap5*theta*0.51)
    BM[148,3] = QW[148,3]*(PAp6*den*Ap6*0.64+z*PAp6*den*Ap6*theta*0.64)
    
    BM[0,4] = QW[0,4]*E[0,f1-1]  
    BM[24,4] = QW[24,4]*(PMa2*den*Ma2*4.25+z*PMa2*den*Ma2*theta*4.25)
    BM[66,4] = QW[66,4]*(PMa3*den*Ma3*2.98+z*PMa3*den*Ma3*theta*2.98)
    BM[72,4] = QW[72,4]*(PMa4*den*Ma4*15+z*PMa4*den*Ma4*theta*15)
    BM[88,4] = QW[88,4]*(PMa5*den*Ma5*18.08+z*PMa5*den*Ma5*theta*18.08)
    BM[148,4] = QW[148,4]*(PMa6*den*Ma6*0.55+z*PMa6*den*Ma6*theta*0.55)
    
    BM[0,5] = QW[0,5]*E[0,g1-1]  
    BM[24,5] = QW[24,5]*(PJun2*den*Jun2*0.30+z*PJun2*den*Jun2*theta*0.30)
    BM[66,5] = QW[66,5]*(PJun3*den*Jun3*0.47+z*PJun3*den*Jun3*theta*0.47)
    BM[72,5] = QW[72,5]*(PJun4*den*Jun4*0.57+z*PJun4*den*Jun4*theta*0.57)
    BM[88,5] = QW[88,5]*(PJun5*den*Jun5*0.54+z*PJun5*den*Jun5*theta*0.54)
    BM[148,5] = QW[148,5]*(PJun6*den*Jun6*0.54+z*PJun6*den*Jun6*theta*0.54)
    
    BM[0,6] = QW[0,6]*E[0,h1-1]  
    BM[24,6] = QW[24,6]*(PJul2*den*Jul2*0.21+z*PJul2*den*Jul2*theta*0.21)
    BM[66,6] = QW[66,6]*(PJul3*den*Jul3*0.37+z*PJul3*den*Jul3*theta*0.37)
    BM[72,6] = QW[72,6]*(PJul4*den*Jul4*0.47+z*PJul4*den*Jul4*theta*0.47)
    BM[88,6] = QW[88,6]*(PJul5*den*Jul5*0.42+z*PJul5*den*Jul5*theta*0.42)
    BM[148,6] = QW[148,6]*(PJul6*den*Jul6*0.47+z*PJul6*den*Jul6*theta*0.47)
    
    BM[0,7] = QW[0,7]*E[0,i1-1]  
    BM[24,7] = QW[24,7]*(PAu2*den*Au2*0.19+z*PAu2*den*Au2*theta*0.19)
    BM[66,7] = QW[66,7]*(PAu3*den*Au3*0.4+z*PAu3*den*Au3*theta*0.4)
    BM[72,7] = QW[72,7]*(PAu4*den*Au4*0.45+z*PAu4*den*Au4*theta*0.45)
    BM[88,7] = QW[88,7]*(PAu5*den*Au5*0.37+z*PAu5*den*Au5*theta*0.37)
    BM[148,7] = QW[148,7]*(PAu6*den*Au6*0.38+z*PAu6*den*Au6*theta*0.38)
    
    BM[0,8] = QW[0,8]*E[0,j1-1]  
    BM[24,8] = QW[24,8]*(PS2*den*S2*0.18+z*PS2*den*S2*theta*0.18)
    BM[66,8] = QW[66,8]*(PS3*den*S3*0.37+z*PS3*den*S3*theta*0.37)
    BM[72,8] = QW[72,8]*(PS4*den*S4*0.35+z*PS4*den*S4*theta*0.35)
    BM[88,8] = QW[88,8]*(PS5*den*S5*0.39+z*PS5*den*S5*theta*0.39)
    BM[148,8] = QW[148,8]*(PS6*den*S6*0.45+z*PS6*den*S6*theta*0.45)
    
    BM[0,9] = QW[0,9]*E[0,k1-1]  
    BM[24,9] = QW[24,9]*(PO2*den*O2*0.22+z*PO2*den*O2*theta*0.22)
    BM[66,9] = QW[66,9]*(PO3*den*O3*0.34+z*PO3*den*O3*theta*0.34)
    BM[72,9] = QW[72,9]*(PO4*den*O4*0.42+z*PO4*den*O4*theta*0.42)
    BM[88,9] = QW[88,9]*(PO5*den*O5*0.34+z*PO5*den*O5*theta*0.34)
    BM[148,9] = QW[148,9]*(PO6*den*O6*0.4+z*PO6*den*O6*theta*0.4)
    
    BM[0,10] = QW[0,10]*E[0,l1-1]  
    BM[24,10] = QW[24,10]*(PN2*den*N2*0.3+z*PN2*den*N2*theta*0.3)
    BM[66,10] = QW[66,10]*(PN3*den*N3*0.3+z*PN3*den*N3*theta*0.3)
    BM[72,10] = QW[72,10]*(PN4*den*N4*0.41+z*PN4*den*N4*theta*0.41)
    BM[88,10] = QW[88,10]*(PN5*den*N5*0.34+z*PN5*den*N5*theta*0.34)
    BM[148,10] = QW[148,10]*(PN6*den*N6*0.4+z*PN6*den*N6*theta*0.4)
    
    BM[0,11] = QW[0,11]*E[0,m1-1]  
    BM[24,11] = QW[24,11]*(PD2*den*D2*0.27+z*PD2*den*D2*theta*0.27)
    BM[66,11] = QW[66,11]*(PD3*den*D3*0.33+z*PD3*den*D3*theta*0.33)
    BM[72,11] = QW[72,11]*(PD4*den*D4*0.46+z*PD4*den*D4*theta*0.46)
    BM[88,11] = QW[88,11]*(PD5*den*D5*0.43+z*PD5*den*D5*theta*0.43)
    BM[148,11] = QW[148,11]*(PD6*den*D6*0.45+z*PD6*den*D6*theta*0.45)
    
    
    #special time step at n=0
    A = A1[:,0]
    B = BM[:,0]
    L11 = np.multiply(L1,Q[0:M+1,0])
    L22 = np.multiply(L2,A)
    Z1 = np.multiply(Z,A)
    M1 = Z1 / dt +  (L11 + L22*K)
    E[:,1] = np.linalg.solve(M1, B)
    Em[:,1] = E[:,1] + C[:,0]
    S[0,1] = S[0,a1]
    S[1:b2,1] = Em[1:b2,1] / (den*PJ1*hb+z*den*PJ1*hb*theta)
    S[b2:c2,1] = Em[b2:c2,1] / (den*PeriBamGuadJ*hb+z*den*PeriBamGuadJ*hb*theta)
    S[c2:d2,1] = Em[c2:d2,1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
    S[d2:e2,1] = Em[d2:e2,1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
    S[e2:f2,1] = Em[e2:f2,1] / (den*PeriGuadLamJ*hb+z*den*PeriGuadLamJ*hb*theta)
    S[f2:g2,1] = Em[f2:g2,1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
    S[g2:h2,1] = Em[g2:h2,1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
    E[0:b2,1] = den*PJ1*hb*S[0:b2,1]
    E[b2:c2,1] = den*PeriBamGuadJ*hb*S[b2:c2,1]
    E[c2:d2,1] = den*PeriGuadJ*hb*S[c2:d2,1]
    E[d2:e2,1] = den*PeriGuadJ*hb*S[d2:e2,1]
    E[e2:f2,1] = den*PeriGuadLamJ*hb*S[e2:f2,1]
    E[f2:g2,1] = den*PeriLamJ*hb*S[f2:g2,1]
    E[g2:h2,1] = den*PeriLamJ*hb*S[g2:h2,1]
    C[:,1] = z*S[:,1]
    
    
    for n in range(1,N):
        #update all matrices
        if n<=b1: #January
            A = A1[:,0]
            B = BM[:,0]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJ1*den*hb*0.27
            RHS[M] = -131*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0,a1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PJ1*hb+z*den*PJ1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadJ*hb+z*den*PeriBamGuadJ*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamJ*hb+z*den*PeriGuadLamJ*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
            E[0:b2,n+1] = den*PJ1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadJ*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadJ*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadJ*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamJ*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamJ*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamJ*hb*S[g2:h2,n+1]
            C[:,n+1] = z*S[:,n+1]
            
        if b1<n<=c1: #February
            A = A1[:,1]
            B = BM[:,1]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJ1*den*hb*0.33
            RHS[M] = -61*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, c1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PF1*hb+z*den*PF1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadF*hb+z*den*PeriBamGuadF*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadF*hb+z*den*PeriGuadF*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadF*hb+z*den*PeriGuadF*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamF*hb+z*den*PeriGuadLamF*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamF*hb+z*den*PeriLamF*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamF*hb+z*den*PeriLamF*hb*theta)
            E[0:b2,n+1] = den*PF1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadF*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadF*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadF*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamF*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamF*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamF*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if c1<n<=d1: #March
            A = A1[:,2]
            B = BM[:,2]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PMar1*den*hb*0.32
            RHS[M] = -140*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, d1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PMar1*hb+z*den*PMar1*1*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadMar*hb+z*den*PeriBamGuadMar*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadMar*hb+z*den*PeriGuadMar*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadMar*hb+z*den*PeriGuadMar*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamMar*hb+z*den*PeriGuadLamMar*1*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamMar*hb+z*den*PeriLamMar*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamMar*hb+z*den*PeriLamMar*hb*theta)
            E[0:b2,n+1] = den*PMar1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadMar*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadMar*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadMar*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamMar*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamMar*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamMar*hb*S[g2:h2,n+1]
            C[:,n+1] = z* S[:,n+1]
            
        if d1<n<=e1: #April
            A = A1[:,3]
            B = BM[:,3]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PAp1*den*hb*0.37
            RHS[M] = -120*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, e1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PAp1*hb+z*den*PAp1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadAp*hb+z*den*PeriBamGuadAp*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadAp*hb+z*den*PeriGuadAp*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadAp*hb+z*den*PeriGuadAp*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamAp*hb+z*den*PeriGuadLamAp*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamAp*hb+z*den*PeriLamAp*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamAp*hb+z*den*PeriLamAp*hb*theta)
            E[0:b2,n+1] = den*PAp1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadAp*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadAp*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadAp*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamAp*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamAp*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamAp*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if e1<n<=f1: #May
            A = A1[:,4]
            B = BM[:,4]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) +B
            RHS[0] = PMa1*den*hb*9.13
            RHS[M] = -84*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, f1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PMa1*hb+z*den*PMa1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadMa*hb+z*den*PeriBamGuadMa*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadMa*hb+z*den*PeriGuadMa*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadMa*hb+z*den*PeriGuadMa*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamMa*hb+z*den*PeriGuadLamMa*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamMa*hb+z*den*PeriLamMa*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamMa*hb+z*den*PeriLamMa*hb*theta)
            E[0:b2,n+1] = den*PMa1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadMa*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadMa*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadMa*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamMa*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamMa*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamMa*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if f1<n<=g1: #June
            A = A1[:,5] 
            B = BM[:,5]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJun1*den*hb*0.53
            RHS[M] = -105*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, g1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PJun1*hb+z*den*PJun1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadJun*hb+z*den*PeriBamGuadJun*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadJun*hb+z*den*PeriGuadJun*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadJun*hb+z*den*PeriGuadJun*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamJun*hb+z*den*PeriGuadLamJun*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamJun*hb+z*den*PeriLamJun*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamJun*hb+z*den*PeriLamJun*hb*theta)
            E[0:b2,n+1] = den*PJun1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadJun*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadJun*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadJun*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamJun*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamJun*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamJun*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if g1<n<=h1: #July
            A = A1[:,6]
            B = BM[:,6]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJul1*den*hb*0.32
            RHS[M] = -331*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, h1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PJul1*hb+z*den*PJul1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadJul*hb+z*den*PeriBamGuadJul*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadJul*hb+z*den*PeriGuadJul*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadJul*hb+z*den*PeriGuadJul*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamJul*hb+z*den*PeriGuadLamJul*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamJul*hb+z*den*PeriLamJul*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamJul*hb+z*den*PeriLamJul*hb*theta)
            E[0:b2,n+1] = den*PJul1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadJul*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadJul*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadJul*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamJul*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamJul*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamJul*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if h1<n<=i1: #August
            A = A1[:,7]
            B = BM[:,7]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PAu1*den*hb*0.34
            RHS[M] = -215*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, i1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PAu1*hb+z*den*PAu1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadAu*hb+z*den*PeriBamGuadAu*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadAu*hb+z*den*PeriGuadAu*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadAu*hb+z*den*PeriGuadAu*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamAu*hb+z*den*PeriGuadLamAu*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamAu*hb+z*den*PeriLamAu*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamAu*hb+z*den*PeriLamAu*hb*theta)
            E[0:b2,n+1] = den*PAu1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadAu*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadAu*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadAu*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamAu*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamAu*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamAu*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if i1<n<=j1: #September
            A = A1[:,8]
            B = BM[:,8]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PS1*den*hb*0.32
            RHS[M] = -214*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, j1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PS1*hb+z*den*PS1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadS*hb+z*den*PeriBamGuadS*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadS*hb+z*den*PeriGuadS*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadS*hb+z*den*PeriGuadS*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamS*hb+z*den*PeriGuadLamS*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamS*hb+z*den*PeriLamS*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamS*hb+z*den*PeriLamS*hb*theta)
            E[0:b2,n+1] = den*PS1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadS*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadS*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadS*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamS*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamS*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamS*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if j1<n<=k1: #October
            A = A1[:,9]
            B = BM[:,9]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PO1*den*hb*0.26
            RHS[M] = -123*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, k1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PO1*hb+z*den*PO1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadO*hb+z*den*PeriBamGuadO*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadO*hb+z*den*PeriGuadO*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadO*hb+z*den*PeriGuadO*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamO*hb+z*den*PeriGuadLamO*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamO*hb+z*den*PeriLamO*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamO*hb+z*den*PeriLamO*hb*theta)
            E[0:b2,n+1] = den*PO1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadO*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadO*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadO*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamO*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamO*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamO*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if k1<n<=l1: #November
            A = A1[:,10]
            B = BM[:,10]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PN1*den*hb*0.26
            RHS[M] = -174*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, l1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PN1*hb+z*den*PN1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadN*hb+z*den*PeriBamGuadN*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadN*hb+z*den*PeriGuadN*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadN*hb+z*den*PeriGuadN*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamN*hb+z*den*PeriGuadLamN*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamN*hb+z*den*PeriLamN*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamN*hb+z*den*PeriLamN*hb*theta)
            E[0:b2,n+1] = den*PN1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadN*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadN*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadN*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamN*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamN*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamN*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if l1<n<=m1: #December
            A = A1[:,10]
            B = BM[:,10]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt #- (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PD1*den*hb*0.27
            RHS[M] = -156*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, m1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PD1*hb+z*den*PD1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadD*hb+z*den*PeriBamGuadD*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadD*hb+z*den*PeriGuadD*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadD*hb+z*den*PeriGuadD*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamD*hb+z*den*PeriGuadLamD*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamD*hb+z*den*PeriLamD*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamD*hb+z*den*PeriLamD*hb*theta)
            E[0:b2,n+1] = den*PD1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadD*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadD*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadD*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamD*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamD*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamD*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
    return   S, x, t, E

# %%
a2 = 0
b2 = 20
c2 = 58
d2 = 78
e2 = 101
f2 = 147
g2 = 171
h2 = 181

# %%
A1 = np.zeros((M+1,12))
A = np.zeros((M+1))
A1[0:20,0] = 255
A1[20:58,0] = 276
A1[58:78,0] = 296
A1[78:101,0] = 296
A1[101:147,0] = 271
A1[147:171,0] = 247
#A1[171:181,0] = 247

A1[0:20,1] = 261
A1[20:58,1] = 242
A1[58:78,1] = 223
A1[78:101,1] = 223
A1[101:147,1] = 264
A1[147:171,1] = 306
#A1[171:181,1] = 306

A1[0:20,2] = 249
A1[20:58,2] = 249
A1[58:78,2] = 249
A1[78:101,2] = 249
A1[101:147,2] = 287
A1[147:171,2] = 326
#A1[171:181,2] = 326

A1[0:20,3] = 262
A1[20:58,3] = 280
A1[58:78,3] = 299
A1[78:101,3] = 299
A1[101:147,3] = 338
A1[147:171,3] = 377
#A1[171:181,3] = 377 

A1[0:20,4] = 288
A1[20:58,4] = 259
A1[58:78,4] = 230
A1[78:101,4] = 230
A1[101:147,4] = 277
A1[147:171,4] = 323
#A1[171:181,4] = 323

A1[0:20,5] = 244
A1[20:58,5] = 237
A1[58:78,5] = 230
A1[78:101,5] = 230
A1[101:147,5] = 289
A1[147:171,5] = 349
#A1[171:181,5] = 349

A1[0:20,6] = 278
A1[20:58,6] = 260
A1[58:78,6] = 243
A1[78:101,6] = 243
A1[101:147,6] = 318
A1[147:171,6] = 394
#A1[171:181,6] = 394

A1[0:20,7] = 262
A1[20:58,7] = 251
A1[58:78,7] = 241
A1[78:101,7] = 241
A1[101:147,7] = 264
A1[147:171,7] = 286
#A1[171:181,7] = 286

A1[0:20,8] = 223
A1[20:58,8] = 230
A1[58:78,8] = 238
A1[78:101,8] = 238
A1[101:147,8] = 249
A1[147:171,8] = 261
#A1[171:181,8] = 261

A1[0:20,9] = 258
A1[20:58,9] = 195
A1[58:78,9] = 131
A1[78:101,9] = 131
A1[101:147,9] = 144
A1[147:171,9] = 156
#A1[171:181,9] = 156

A1[0:20,10] = 198
A1[20:58,10] = 222
A1[58:78,10] = 245
A1[78:101,10] = 245
A1[101:147,10] = 259
A1[147:171,10] = 272
#A1[171:181,10] = 272

A1[0:20,11] = 187
A1[20:58,11] = 176
A1[58:78,11] = 165
A1[78:101,11] = 165
A1[101:147,11] = 230
A1[147:171,11] = 295
#A1[171:181,11] = 295


Q = np.zeros((M+1,N+1))

Q[a2:b2,0:b1] = 151 #Jan
Q[b2:c2,0:b1] = 86
Q[c2:d2,0:b1] = 21
Q[d2:e2,0:b1] = 21
Q[e2:f2,0:b1] = 76
Q[f2:g2,0:b1] = 131
#Q[g2:h2,0:b1] = 131

Q[a2:b2,b1:c1] = 71 #Feb
Q[b2:c2,b1:c1] = 83
Q[c2:d2,b1:c1] = 96
Q[d2:e2,b1:c1] = 96
Q[e2:f2,b1:c1] = 51
Q[f2:g2,b1:c1] = 6
#Q[g2:h2,b1:c1] = 6

Q[a2:b2,c1:d1] = 117 #Mar
Q[b2:c2,c1:d1] = (117+128)/2
Q[c2:d2,c1:d1] = 128
Q[d2:e2,c1:d1] = 128
Q[e2:f2,c1:d1] = (137+140)/2
Q[f2:g2,c1:d1] = 140
#Q[g2:h2,c1:d1] = 140

Q[a2:b2,d1:e1] = 60 #April
Q[b2:c2,d1:e1] = (60+33)/2
Q[c2:d2,d1:e1] = 33
Q[d2:e2,d1:e1] = 33
Q[e2:f2,d1:e1] = (33+120)/2
Q[f2:g2,d1:e1] = 120
#Q[g2:h2,d1:e1] = 120

Q[a2:b2,e1:f1] = 184 # May
Q[b2:c2,e1:f1] = (184+74)/2
Q[c2:d2,e1:f1] = 74
Q[d2:e2,e1:f1] = 74
Q[e2:f2,e1:f1] = (74+84)/2
Q[f2:g2,e1:f1] = 84
#Q[g2:h2,e1:f1] = 84

Q[a2:b2,f1:g1] = 88 #June
Q[b2:c2,f1:g1] = (88+51)/2
Q[c2:d2,f1:g1] = 51
Q[d2:e2,f1:g1] = 51
Q[e2:f2,f1:g1] = (51+105)/2
Q[f2:g2,f1:g1] = 105
#Q[g2:h2,f1:g1] = 105

Q[a2:b2,g1:h1] = 286 #July
Q[b2:c2,g1:h1] = 228
Q[c2:d2,g1:h1] = 170
Q[d2:e2,g1:h1] = 170
Q[e2:f2,g1:h1] = 250
Q[f2:g2,g1:h1] = 331
#Q[g2:h2,g1:h1] = 331

Q[a2:b2,h1:i1] = 63 # Aug
Q[b2:c2,h1:i1] = 124
Q[c2:d2,h1:i1] = 186
Q[d2:e2,h1:i1] = 186
Q[e2:f2,h1:i1] = 200
Q[f2:g2,h1:i1] = 215
#Q[g2:h2,h1:i1] = 215

Q[a2:b2,i1:j1] = 80 #September
Q[b2:c2,i1:j1] = 136
Q[c2:d2,i1:j1] = 193
Q[d2:e2,i1:j1] = 193
Q[e2:f2,i1:j1] = 203
Q[f2:g2,i1:j1] = 214
#Q[g2:h2,i1:j1] = 214

Q[a2:b2,j1:k1] = 323 #October
Q[b2:c2,j1:k1] = 180
Q[c2:d2,j1:k1] = 37
Q[d2:e2,j1:k1] = 37
Q[e2:f2,j1:k1] = 80
Q[f2:g2,j1:k1] = 123
#Q[g2:h2,j1:k1] = 123

Q[a2:b2,k1:l1] = 214 #November
Q[b2:c2,k1:l1] = 108
Q[c2:d2,k1:l1] = 2
Q[d2:e2,k1:l1] = 2
Q[e2:f2,k1:l1] = 88
Q[f2:g2,k1:l1] = 174
#Q[g2:h2,k1:l1] = 174

Q[a2:b2,l1:m1-1] = 125
Q[b2:c2,l1:m1-1] = 87
Q[c2:d2,l1:m1-1] = 49
Q[d2:e2,l1:m1-1] = 49
Q[e2:f2,l1:m1-1] = 103
Q[f2:g2,l1:m1-1] = 156
#Q[g2:h2,l1:m1-1] = 156

# %%
from scipy.integrate import quad
#Solving for matrices L1, L2, L3
T =  31104000
L = 8500
den = 0.01       #density of CIMW and CMW
theta = 1       #porosity
l = 50          #element distance
K = 1000         #dispersion coefficient K=diffusion+dispersitivity*fv
dt = 360        #time step size
dx = 50
N = int(round(T/dt))          #no. of time steps
M = int(round(L/dx))          #no. of nodes

#Solving for L1, let E=E^m/E (to be solve)
def integrand(x):
    return -(-1/l)*(1-x/l)
ans1, err = quad(integrand, 0, l)

def integrand(x):
    return -(-1/l)*(x/l)
ans2, err = quad(integrand, 0, l)

def integrand(x):
    return -(1/l)*(1-x/l)
ans3, err = quad(integrand, 0, l)

def integrand(x):
    return -(1/l)*(x/l)
ans4, err = quad(integrand, 0, l)

L1 = diags([ans3,(ans1+ans4),ans2], [-1,0,1], shape=(M+1, M+1)).toarray()
L1[0, 0] = ans1
L1[M, M] = ans4
#L1 is to be multiplied by Q

#Solving for L2

def integrand(x):
    return (-1/l)*(-1/l)
ans12, err = quad(integrand, 0, l)

def integrand(x):
    return (-1/l)*(1/l)
ans13, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(-1/l)
ans14, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(1/l)
ans15, err = quad(integrand, 0, l)

L2 = diags([ans14,(ans12+ans15),ans13], [-1,0,1], shape=(M+1, M+1)).toarray()
L2[0,0] = ans12
L2[M,M] = ans15
#L2 is to be multiplied by K and A

#Solving for L3 is zero.

#Solving for M

def integrand(x):
    return (1-x/l)*(1-x/l)
ans20, err = quad(integrand, 0, l)

def integrand(x):
    return (1-x/l)*(x/l)
ans21, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(1-x/l)
ans22, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(x/l)
ans23, err = quad(integrand, 0, l)

Z = diags([ans22,(ans20+ans23),ans21], [-1,0,1], shape=(M+1, M+1)).toarray()
Z[0, 0] = ans20
Z[M, M] = ans23


(S,x,t, E) = solver(T,dt,L1, L2, Z)

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"], [0.27, 0.32, 0.31, 0.37, 16.58, 0.48, 0.31, 0.33, 0.32, 0.29, 0.26, 0.27], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"],[S[72,7200], S[72,14400], S[72,21600], S[72,28800], S[72,36000], S[72,43200], S[72,50400], S[72,57600], S[72,64800], S[72,72000], S[72,79200], S[72,86400]], 'bs')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"],[0.2651862626039011, 0.3229904989246456, 0.29916543887657127, 0.38120211605308185, 8.746234433538744, 0.5200498057306365, 0.2955792488815263, 0.32542985034921135, 0.2971136841376502, 0.2512095130449564, 0.3671174020813108, 0.2553288471177648], 'gs')

plt.legend(["actual","OS", "OS with LEM"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("MTDS($g/m^3$)")
plt.title("TDS Guadalupe 2018, $K=1000$")
plt.savefig('TDS Guadalupe 2018.png') 

plt.show()

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()

plt.ylim(0, 1.5)
plt.plot(["Jan", "Feb", "Mar", "Apr", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"], [0.27, 0.32, 0.31, 0.37, 0.48, 0.31, 0.33, 0.32, 0.29, 0.26, 0.27], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"],[S[72,7200], S[72,14400], S[72,21600], S[72,28800], S[72,43200], S[72,50400], S[72,57600], S[72,64800], S[72,72000], S[72,79200], S[72,86400]], 'bs')
plt.plot(["Jan", "Feb", "Mar", "Apr", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"],[0.2651862626039011, 0.3229904989246456, 0.29916543887657127, 0.38120211605308185, 0.5200498057306365, 0.2955792488815263, 0.32542985034921135, 0.2971136841376502, 0.2512095130449564, 0.3671174020813108, 0.2553288471177648], 'gs')

plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("MTDS($g/m^3$)")
plt.title("TDS Guadalupe 2018, $K=1000$")
#plt.savefig('TDS Guadalupe 2018, $K=1000$, except May.png') 

plt.show()

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"], [0.25, 0.30, 0.35, 0.87, 22.25, 0.48, 0.32, 0.32, 0.32, 0.28, 0.28, 0.28], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"],[S[170,7200], S[170,14400], S[170,21600], S[170,28800], S[170,36000], S[170,43200], S[170,50400], S[170,57600], S[170,64800], S[170,72000], S[170,79200], S[170,86400]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("MTDS($g/m^3$)")
plt.title("TDS Lambingan 2018, $K=1000$")
#plt.savefig('TDS Lambingan 2018, $K=1000$.png') 

plt.show()

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()

plt.ylim(0, 1)
plt.plot(["Jan", "Feb", "Mar", "Apr", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"], [0.25, 0.30, 0.35, 0.87, 0.48, 0.32, 0.32, 0.32, 0.28, 0.28, 0.28], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"],[S[170,7200], S[170,14400], S[170,21600], S[170,28800], S[170,43200], S[170,50400], S[170,57600], S[170,64800], S[170,72000], S[170,79200], S[170,86400]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("MTDS($g/m^3$)")
plt.title("TDS Lambingan 2018, $K=1000$")
#plt.savefig('TDS Lambingan 2018, $K=1000$, except May.png') 

plt.show()
