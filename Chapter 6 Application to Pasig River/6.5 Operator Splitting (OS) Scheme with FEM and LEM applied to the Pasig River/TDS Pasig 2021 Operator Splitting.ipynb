# %%
from scipy.sparse import diags #linalg
from scipy.linalg import solve
import numpy as np
from numpy.linalg import inv, det
from matplotlib import pyplot as plt

# %%
a1 = 0 
b1 = 7200
c1 = 2*b1
d1 = 3*b1
e1 = 4*b1
f1 = 5*b1
g1 = 6*b1
h1 = 7*b1
i1 = 8*b1
j1 = 9*b1
k1 = 10*b1
l1 = 11*b1
m1 = 12*b1
n1 = 13*b1
o1 = 14*b1
p1 = 15*b1
q1 = 16*b1
r1 = 17*b1

z = 0.01

# %%
#Depth per month of the sources
J1 = 3.5
J2 = 0
J3 = 0
J4 = 1.5
J5 = 1.06
J6 = 1.4

F1 = 4.46
F2 = 0
F3 = 0
F4 = 0.53
F5 = 0.93
F6 = 0.63

Mar1 = 2.8
Mar2 = 0 
Mar3 = 0
Mar4 = 0.26
Mar5 = 0.8
Mar6 = 1.56

Ap1 = 2.3
Ap2 = 0
Ap3 = 0
Ap4 = 0.33
Ap5 = 0.96
Ap6 = 0.96

Ma1 = 2.9
Ma2 = 0
Ma3 = 0
Ma4 = 0.63
Ma5 = 1.23
Ma6 = 0.96

Jun1 = 2.5
Jun2 = 0
Jun3 = 0
Jun4 = 0.56
Jun5 = 1.5
Jun6 = 1

Jul1 = 2.66
Jul2 = 0
Jul3 = 0
Jul4 = 0.86
Jul5 = 1.03
Jul6 = 0.9

Au1 = 3.9
Au2 = 0
Au3 = 0
Au4 = 0.66
Au5 = 0.96
Au6 = 2.1

S1 = 3.26
S2 = 0
S3 = 0
S4 = 1
S5 = 1.2
S6 = 1.6

O1 = 3.4
O2 = 0
O3 = 0
O4 = 1.3
O5 = 1.5
O6 = 1.7

N1 = 3.9
N2 = 0
N3 = 0
N4 = 0.83
N5 = 1.06
N6 = 1.4

D1 = 3.5
D2 = 0
D3 = 0
D4 = 0.23
D5 = 1.5
D6 = 0.63

# %%
#Wetted Perimeter
PJ1 = 2*J1 + 65
PJ2 = 2*J2 + 53
PJ3 = 2*J3 + 7
PJ4 = 2*J4 + 7
PJ5 = 2*J5 + 9
PJ6 = 2*J6 + 7

PF1 = 2*F1 + 65
PF2 = 2*F2 + 53
PF3 = 2*F3 + 7
PF4 = 2*F4 + 7
PF5 = 2*F5 + 9
PF6 = 2*F6 + 7

PMar1 = 2*Mar1 +  65
PMar2 = 2*Mar2 +  53
PMar3 = 2*Mar3 +  7
PMar4 = 2*Mar4 +  7
PMar5 = 2*Mar5 +  9
PMar6 = 2*Mar6 +  7

PAp1 = 2*Ap1 + 65
PAp2 = 2*Ap2 + 53
PAp3 = 2*Ap3 + 7
PAp4 = 2*Ap4 + 7
PAp5 = 2*Ap5 + 9
PAp6 = 2*Ap6 + 7

PMa1 = 2*Ma1 + 65
PMa2 = 2*Ma2 + 53
PMa3 = 2*Ma3 + 7
PMa4 = 2*Ma4 + 7
PMa5 = 2*Ma5 + 9
PMa6 = 2*Ma6 + 7

PJun1 = 2*Jun1 + 65
PJun2 = 2*Jun2 + 53
PJun3 = 2*Jun3 + 7
PJun4 = 2*Jun4 + 7
PJun5 = 2*Jun5 + 9
PJun6 = 2*Jun6 + 7

PJul1 = 2*Jul1 + 65
PJul2 = 2*Jul2 + 53
PJul3 = 2*Jul3 + 7
PJul4 = 2*Jul4 + 7
PJul5 = 2*Jul5 + 9
PJul6 = 2*Jul6 + 7

PAu1 = 2*Au1 + 65
PAu2 = 2*Au2 + 53
PAu3 = 2*Au3 + 7
PAu4 = 2*Au4 + 7
PAu5 = 2*Au5 + 9
PAu6 = 2*Au6 + 7

PS1 = 2*S1 + 65
PS2 = 2*S2 + 53
PS3 = 2*S3 + 7
PS4 = 2*S4 + 7
PS5 = 2*S5 + 9
PS6 = 2*S6 + 7

PO1 = 2*O1 + 65
PO2 = 2*O2 + 53
PO3 = 2*O3 + 7
PO4 = 2*O4 + 7
PO5 = 2*O5 + 9
PO6 = 2*O6 + 7

PN1 = 2*N1 + 65
PN2 = 2*N2 + 53
PN3 = 2*N3 + 7
PN4 = 2*N4 + 7
PN5 = 2*N5 + 9
PN6 = 2*N6 + 7

PD1 = 2*D1 + 65
PD2 = 2*D2 + 53
PD3 = 2*D3 + 7
PD4 = 2*D4 + 7
PD5 = 2*D5 + 9
PD6 = 2*D6 + 7

# %%
#depth and wetted perimeter of Guadalupe and Lambingan
DepthBamGuadJ = 3.32
DepthBamGuadF = 3.55
DepthBamGuadMar = 2.23
DepthBamGuadAp = 2.52
DepthBamGuadMa = 2.00
DepthBamGuadJun = 2.37
DepthBamGuadJul = 2.55
DepthBamGuadAu = 3.70
DepthBamGuadS = 3.13
DepthBamGuadO = 2.35
DepthBamGuadN = 3.52
DepthBamGuadD = 2.72


DepthGuadJ = 3.13
DepthGuadF = 2.63
DepthGuadMar = 1.66
DepthGuadAp = 2.73
DepthGuadMa = 1.10
DepthGuadJun = 2.23
DepthGuadJul = 2.43
DepthGuadAu = 3.50
DepthGuadS = 3.00
DepthGuadO = 1.30
DepthGuadN = 3.13
DepthGuadD = 1.93

DepthGuadLamJ = 2.98
DepthGuadLamF = 2.17
DepthGuadLamMar = 2.23
DepthGuadLamAp = 3.03
DepthGuadLamMa = 2.72
DepthGuadLamJun = 2.27
DepthGuadLamJul = 2.45
DepthGuadLamAu = 4.53
DepthGuadLamS = 3.92
DepthGuadLamO = 2.25
DepthGuadLamN = 4.27
DepthGuadLamD = 3.17

DepthLamJ = 2.83
DepthLamF = 1.70
DepthLamMar = 2.80
DepthLamAp = 3.33
DepthLamMa = 4.33
DepthLamJun = 2.30
DepthLamJul = 2.46
DepthLamAu = 5.56
DepthLamS = 4.83
DepthLamO = 3.20
DepthLamN = 5.40
DepthLamD = 4.40

PeriBamGuadJ = 2*DepthBamGuadJ + 70
PeriBamGuadF = 2*DepthBamGuadF + 70
PeriBamGuadMar = 2*DepthBamGuadMar + 70
PeriBamGuadAp = 2*DepthBamGuadAp + 70
PeriBamGuadMa = 2*DepthBamGuadMa + 70
PeriBamGuadJun = 2*DepthBamGuadJun + 70
PeriBamGuadJul = 2*DepthBamGuadJul + 70
PeriBamGuadAu = 2*DepthBamGuadAu + 70
PeriBamGuadS = 2*DepthBamGuadS + 70
PeriBamGuadO = 2*DepthBamGuadO + 70
PeriBamGuadN = 2*DepthBamGuadN + 70
PeriBamGuadD = 2*DepthBamGuadD + 70

PeriGuadJ = 2*DepthGuadJ + 76
PeriGuadF =  2*DepthGuadF + 76
PeriGuadMar =  2*DepthGuadMar + 76
PeriGuadAp =  2*DepthGuadAp + 76
PeriGuadMa =  2*DepthGuadMa + 76
PeriGuadJun =  2*DepthGuadJun + 76
PeriGuadJul =  2*DepthGuadJul + 76
PeriGuadAu =  2*DepthGuadAu + 76
PeriGuadS =  2*DepthGuadS + 76
PeriGuadO =  2*DepthGuadO + 76
PeriGuadN =  2*DepthGuadN + 76
PeriGuadD =  2*DepthGuadD + 76

PeriGuadLamJ = 2*DepthGuadLamJ + 80
PeriGuadLamF = 2*DepthGuadLamF + 80
PeriGuadLamMar = 2*DepthGuadLamMar + 80
PeriGuadLamAp = 2*DepthGuadLamAp + 80
PeriGuadLamMa = 2*DepthGuadLamMa + 80
PeriGuadLamJun = 2*DepthGuadLamJun + 80
PeriGuadLamJul = 2*DepthGuadLamJul + 80
PeriGuadLamAu = 2*DepthGuadLamAu + 80
PeriGuadLamS = 2*DepthGuadLamS + 80
PeriGuadLamO = 2*DepthGuadLamO + 80
PeriGuadLamN = 2*DepthGuadLamN + 80
PeriGuadLamD = 2*DepthGuadLamD + 80

PeriLamJ = 2*DepthLamJ + 85
PeriLamF = 2*DepthLamF + 85
PeriLamMar = 2*DepthLamMar + 85
PeriLamAp = 2*DepthLamAp + 85
PeriLamMa = 2*DepthLamMa + 85
PeriLamJun = 2*DepthLamJun + 85
PeriLamJul = 2*DepthLamJul + 85
PeriLamAu = 2*DepthLamAu + 85
PeriLamS = 2*DepthLamS + 85
PeriLamO = 2*DepthLamO + 85
PeriLamN = 2*DepthLamN + 85
PeriLamD = 2*DepthLamD + 85

hb = 1

# %%
def solver(T,dt,L1, L2, L3, Z):
    N = int(round(T/dt))
    t = np.linspace(0,T,N+1) #time discrete
    M = int(round(L/dx))
    x = np.linspace(0,L,M+1) #space discrete
    E = np.zeros((M+1,N+1))
    S = np.zeros((M+1,N+1))
    C = np.zeros((M+1,N+1))
    PPX = np.zeros((M+1))
    Em = np.zeros((M+1,N+1))
    BM = np.zeros((M+1,12))
    Bi = np.zeros((M+1))
    RHS = np.zeros((M+1))
    B = np.zeros((M+1))
    A = np.zeros((M+1))
    QW = np.zeros((M+1,12))
    
    #initial conditions
    S[0,a1:b1] = 0.539
    S[0,b1:c1] = 0.42
    S[0,c1:d1] = 0.49
    S[0,d1:e1] = 0.46
    S[0,e1:f1] = 0.40
    S[0,f1:g1] = 0.45
    S[0,g1:h1] = 0.45
    S[0,h1:i1] = 0.37
    S[0,i1:j1] = 0.30
    S[0,j1:k1] = 1.36
    S[0,k1:l1] = 0.30
    S[0,l1:m1] = 0.30
    C[0,a1:b1] = z*S[0,a1:b1]
    C[0,b1:c1] = z*S[0,b1:c1]
    C[0,c1:d1] = z*S[0,c1:d1]
    C[0,d1:e1] = z*S[0,d1:e1]
    C[0,e1:f1] = z*S[0,e1:f1]
    C[0,f1:g1] = z*S[0,f1:g1]
    C[0,g1:h1] = z*S[0,g1:h1]
    C[0,h1:i1] = z*S[0,h1:i1]
    C[0,i1:j1] = z*S[0,i1:j1]
    C[0,j1:k1] = z*S[0,j1:k1]
    C[0,k1:l1] = z*S[0,k1:l1]
    C[0,l1:m1] = z*S[0,l1:m1]
    E[0,a1:b1] = PJ1*den*hb*S[0,a1:b1]
    E[0,b1:c1] = PF1*den*hb*S[0,b1:c1]
    E[0,c1:d1] = PMar1*den*hb*S[0,c1:d1]
    E[0,d1:e1] = PAp1*den*hb*S[0,d1:e1]
    E[0,e1:f1] = PMa1*den*hb*S[0,e1:f1]
    E[0,f1:g1] = PJun1*den*hb*S[0,f1:g1]
    E[0,g1:h1] = PJul1*den*hb*S[0,g1:h1]
    E[0,h1:i1] = PAu1*den*hb*S[0,h1:i1]
    E[0,i1:j1] = PS1*den*S1*S[0,i1:j1]
    E[0,j1:k1] = PO1*den*hb*S[0,j1:k1]
    E[0,k1:l1] = PN1*den*hb*S[0,k1:l1]
    E[0,l1:m1] = PD1*den*hb*S[0,l1:m1]
    
    #Flow Rate Boundary
    QW[0,0] = 277.55
    QW[24,0] = 0
    QW[66,0] = 0
    QW[72,0] = 2.21
    QW[88,0] = 8.49
    QW[148,0] = 1.5
    
    QW[0,1] = 40.59
    QW[24,1] = 0
    QW[66,1] = 0
    QW[72,1] = 0.48
    QW[88,1] = 0
    QW[148,1] = 2.12
    
    QW[0,2] = 220.22
    QW[24,2] = 0
    QW[66,2] = 0
    QW[72,2] = 0.04
    QW[88,2] = 0.14
    QW[148,2] = 8.52
    
    QW[0,3] = 19.44
    QW[24,3] = 0
    QW[66,3] = 0
    QW[72,3] = 0.72
    QW[88,3] = 8.99
    QW[148,3] = 0.81
    
    QW[0,4] = 65.98
    QW[24,4] = 0
    QW[66,4] = 0
    QW[72,4] = 0.49
    QW[88,4] = 1.22
    QW[148,4] = 7.19
    
    QW[0,5] = 152.75
    QW[24,5] = 0
    QW[66,5] = 0
    QW[72,5] = 3.96
    QW[88,5] = 14.18
    QW[148,5] = 1.05
    
    QW[0,6] = 24.21
    QW[24,6] = 0
    QW[66,6] = 0
    QW[72,6] = 0.84
    QW[88,6] = 1.30
    QW[148,6] = 0.82
    
    QW[0,7] = 55.77
    QW[24,7] = 0
    QW[66,7] = 0
    QW[72,7] = 1.11
    QW[88,7] = 1.99
    QW[148,7] = 1.91
    
    QW[0,8] = 65.69
    QW[24,8] = 0
    QW[66,8] = 0
    QW[72,8] = 1.40
    QW[88,8] = 2.59
    QW[148,8] = 2.91
    
    QW[0,9] = 68.51
    QW[24,9] = 0
    QW[66,9] = 0
    QW[72,9] = 3.64
    QW[88,9] = 3.24
    QW[148,9] = 1.67
    
    QW[0,10] = 30.42
    QW[24,10] = 0
    QW[66,10] = 0
    QW[72,10] = 0.99
    QW[88,10] = 0.95
    QW[148,10] = 1.37
    
    QW[0,11] = 52.33
    QW[24,11] = 0
    QW[66,11] = 0
    QW[72,11] = 0.34
    QW[88,11] = 12.02
    QW[148,11] = 1.19
   
    #boundary/sources
    BM[0,0] = QW[0,0]*(PJ1*den*hb*0.539) 
    BM[24,0] = QW[24,0]*(PJ2*den*J2*0)
    BM[66,0] = QW[66,0]*(PJ3*den*J3*0)
    BM[72,0] = QW[72,0]*(PJ4*den*J4*0.297)
    BM[88,0] = QW[88,0]*(PJ5*den*J5*0.352)
    BM[148,0] = QW[148,0]*(PJ6*den*J6*0.386)
    
    BM[0,1] = QW[0,1]*(PF1*den*hb*0.42)  
    BM[24,1] = QW[24,1]*(PF2*den*F2*0+z*PF2*F2*den*theta*0)
    BM[66,1] = QW[66,1]*(PF3*den*F3*0+z*PF3*F3*den*theta*0)
    BM[72,1] = QW[72,1]*(PF4*den*F4*0.46+z*PF4*F4*den*theta*0.46)
    BM[88,1] = QW[88,1]*(PF5*den*F5*0.41+z*PF5*F5*den*theta*0.41)
    BM[148,1] = QW[148,1]*(PF6*den*F6*0.39+z*PF6*F6*den*theta*0.39)
    
    BM[0,2] = QW[0,2]*(PMar1*den*hb*0.49)  
    BM[24,2] = QW[24,2]*(PMar2*den*Mar2*0+z*PMar2*den*Mar2*theta*0)
    BM[66,2] = QW[66,2]*(PMar3*den*Mar3*0+z*PMar3*den*Mar3*theta*0)
    BM[72,2] = QW[72,2]*(PMar4*den*Mar4*0.46+z*PMar4*den*Mar4*theta*0.46)
    BM[88,2] = QW[88,2]*(PMar5*den*Mar5*0.38+z*PMar5*den*Mar5*theta*0.38)
    BM[148,2] = QW[148,2]*(PMar6*den*Mar6*0.40+z*PMar6*den*Mar6*theta*0.40)
    
    BM[0,3] = QW[0,3]*(PAp1*den*hb*0.46)  
    BM[24,3] = QW[24,3]*(PAp2*den*Ap2*0+z*PAp2*den*Ap2*theta*0)
    BM[66,3] = QW[66,3]*(PAp3*den*Ap3*0+z*PAp3*den*Ap3*theta*0)
    BM[72,3] = QW[72,3]*(PAp4*den*Ap4*0.44+z*PAp4*den*Ap4*theta*0.44)
    BM[88,3] = QW[88,3]*(PAp5*den*Ap5*0.43+z*PAp5*den*Ap5*theta*0.43)
    BM[148,3] = QW[148,3]*(PAp6*den*Ap6*0.37+z*PAp6*den*Ap6*theta*0.37)
    
    BM[0,4] = QW[0,4]*(PMa1*den*hb*0.40)    
    BM[24,4] = QW[24,4]*(PMa2*den*Ma2*0+z*PMa2*den*Ma2*theta*0)
    BM[66,4] = QW[66,4]*(PMa3*den*Ma3*0+z*PMa3*den*Ma3*theta*0)
    BM[72,4] = QW[72,4]*(PMa4*den*Ma4*0.51+z*PMa4*den*Ma4*theta*0.51)
    BM[88,4] = QW[88,4]*(PMa5*den*Ma5*0.42+z*PMa5*den*Ma5*theta*0.42)
    BM[148,4] = QW[148,4]*(PMa6*den*Ma6*0.42+z*PMa6*den*Ma6*theta*0.42)
    
    BM[0,5] = QW[0,5]*(PJun1*den*hb*0.45)  
    BM[24,5] = QW[24,5]*(PJun2*den*Jun2*0+z*PJun2*den*Jun2*theta*0)
    BM[66,5] = QW[66,5]*(PJun3*den*Jun3*0+z*PJun3*den*Jun3*theta*0)
    BM[72,5] = QW[72,5]*(PJun4*den*Jun4*0.45+z*PJun4*den*Jun4*theta*0.45)
    BM[88,5] = QW[88,5]*(PJun5*den*Jun5*0.43+z*PJun5*den*Jun5*theta*0.43)
    BM[148,5] = QW[148,5]*(PJun6*den*Jun6*0.34+z*PJun6*den*Jun6*theta*0.34)
    
    BM[0,6] = QW[0,6]*(PJun1*den*hb*0.45)  
    BM[24,6] = QW[24,6]*(PJul2*den*Jul2*0+z*PJul2*den*Jul2*theta*0)
    BM[66,6] = QW[66,6]*(PJul3*den*Jul3*0+z*PJul3*den*Jul3*theta*0)
    BM[72,6] = QW[72,6]*(PJul4*den*Jul4*0.51+z*PJul4*den*Jul4*theta*0.51)
    BM[88,6] = QW[88,6]*(PJul5*den*Jul5*0.42+z*PJul5*den*Jul5*theta*0.42)
    BM[148,6] = QW[148,6]*(PJul6*den*Jul6*0.36+z*PJul6*den*Jul6*theta*0.36)
    
    BM[0,7] = QW[0,7]*(PAu1*den*hb*0.37)  
    BM[24,7] = QW[24,7]*(PAu2*den*Au2*0+z*PAu2*den*Au2*theta*0)
    BM[66,7] = QW[66,7]*(PAu3*den*Au3*0+z*PAu3*den*Au3*theta*0)
    BM[72,7] = QW[72,7]*(PAu4*den*Au4*0.34+z*PAu4*den*Au4*theta*0.34)
    BM[88,7] = QW[88,7]*(PAu5*den*Au5*0.32+z*PAu5*den*Au5*theta*0.32)
    BM[148,7] = QW[148,7]*(PAu6*den*Au6*0.18+z*PAu6*den*Au6*theta*0.18) 
   
    BM[0,8] = QW[0,8]*(PS1*den*hb*0.30)  
    BM[24,8] = QW[24,8]*(PS2*den*S2*0+z*PS2*den*S2*theta*0)
    BM[66,8] = QW[66,8]*(PS3*den*S3*0+z*PS3*den*S3*theta*0)
    BM[72,8] = QW[72,8]*(PS4*den*S4*0.48+z*PS4*den*S4*theta*0.48)
    BM[88,8] = QW[88,8]*(PS5*den*S5*0.35+z*PS5*den*S5*theta*0.35)
    BM[148,8] = QW[148,8]*(PS6*den*S6*0.33+z*PS6*den*S6*theta*0.33)
    
    BM[0,9] = QW[0,9]*(PO1*den*hb*1.36)
    BM[24,9] = QW[24,9]*(PO2*den*O2*0+z*PO2*den*O2*theta*0)
    BM[66,9] = QW[66,9]*(PO3*den*O3*0+z*PO3*den*O3*theta*0)
    BM[72,9] = QW[72,9]*(PO4*den*O4*0.51+z*PO4*den*O4*theta*0.51)
    BM[88,9] = QW[88,9]*(PO5*den*O5*0.62+z*PO5*den*O5*theta*0.62)
    BM[148,9] = QW[148,9]*(PO6*den*O6*0.86+z*PO6*den*O6*theta*0.86)
    
    BM[0,10] = QW[0,10]*(PN1*den*hb*0.30)  
    BM[24,10] = QW[24,10]*(PN2*den*N2*0+z*PN2*den*N2*theta*0)
    BM[66,10] = QW[66,10]*(PN3*den*N3*0+z*PN3*den*N3*theta*0)
    BM[72,10] = QW[72,10]*(PN4*den*N4*0.45+z*PN4*den*N4*theta*0.45)
    BM[88,10] = QW[88,10]*(PN5*den*N5*0.36+z*PN5*den*N5*theta*0.36)
    BM[148,10] = QW[148,10]*(PN6*den*N6*0.38+z*PN6*den*N6*theta*0.38)
    
    BM[0,11] = QW[0,11]*(PD1*den*hb*0.30)  
    BM[24,11] = QW[24,11]*(PD2*den*D2*0+z*PD2*den*D2*theta*0)
    BM[66,11] = QW[66,11]*(PD3*den*D3*0+z*PD3*den*D3*theta*0)
    BM[72,11] = QW[72,11]*(PD4*den*D4*0.99+z*PD4*den*D4*theta*0.99)
    BM[88,11] = QW[88,11]*(PD5*den*D5*0.36+z*PD5*den*D5*theta*0.36)
    BM[148,11] = QW[148,11]*(PD6*den*D6*0.32+z*PD6*den*D6*theta*0.32)
    
    
    #special time step at n=0
    A = A1[:,0]
    B = BM[:,0]
    L11 = np.multiply(L1,Q[0:M+1,0])
    L22 = np.multiply(L2,A)
    Z1 = np.multiply(Z,A)
    M1 = Z1 / dt +  (L11 + L22*K)
    E[:,1] = np.linalg.solve(M1, B)
    Em[:,1] = E[:,1] + C[:,0]
    S[0,1] = S[0,a1]
    S[1:b2,1] = Em[1:b2,1] / (den*PJ1*hb+z*den*PJ1*hb*theta)
    S[b2:c2,1] = Em[b2:c2,1] / (den*PeriBamGuadJ*hb+z*den*PeriBamGuadJ*hb*theta)
    S[c2:d2,1] = Em[c2:d2,1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
    S[d2:e2,1] = Em[d2:e2,1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
    S[e2:f2,1] = Em[e2:f2,1] / (den*PeriGuadLamJ*hb+z*den*PeriGuadLamJ*hb*theta)
    S[f2:g2,1] = Em[f2:g2,1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
    S[g2:h2,1] = Em[g2:h2,1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
    E[0:b2,1] = den*PJ1*hb*S[0:b2,1]
    E[b2:c2,1] = den*PeriBamGuadJ*hb*S[b2:c2,1]
    E[c2:d2,1] = den*PeriGuadJ*hb*S[c2:d2,1]
    E[d2:e2,1] = den*PeriGuadJ*hb*S[d2:e2,1]
    E[e2:f2,1] = den*PeriGuadLamJ*hb*S[e2:f2,1]
    E[f2:g2,1] = den*PeriLamJ*hb*S[f2:g2,1]
    E[g2:h2,1] = den*PeriLamJ*hb*S[g2:h2,1]
    C[:,1] = z*S[:,1]
    
    
    for n in range(1,N):
        #update all matrices
        if n<=b1: #January
            A = A1[:,0]
            B = BM[:,0]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJ1*den*hb*0.539
            RHS[M] = -24.06*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0,a1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PJ1*hb+z*den*PJ1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadJ*hb+z*den*PeriBamGuadJ*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamJ*hb+z*den*PeriGuadLamJ*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
            E[0:b2,n+1] = den*PJ1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadJ*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadJ*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadJ*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamJ*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamJ*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamJ*hb*S[g2:h2,n+1]
            C[:,n+1] = z*S[:,n+1]
            
        if b1<n<=c1: #February
            A = A1[:,1]
            B = BM[:,1]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJ1*den*hb*0.42
            RHS[M] = -315.01*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0,c1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PF1*hb+z*den*PF1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadF*hb+z*den*PeriBamGuadF*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadF*hb+z*den*PeriGuadF*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadF*hb+z*den*PeriGuadF*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamF*hb+z*den*PeriGuadLamF*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamF*hb+z*den*PeriLamF*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamF*hb+z*den*PeriLamF*hb*theta)
            E[0:b2,n+1] = den*PF1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadF*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadF*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadF*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamF*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamF*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamF*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if c1<n<=d1: #March
            A = A1[:,2]
            B = BM[:,2]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PMar1*den*hb*0.49
            RHS[M] = -7.14*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0,d1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PMar1*hb+z*den*PMar1*1*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadMar*hb+z*den*PeriBamGuadMar*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadMar*hb+z*den*PeriGuadMar*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadMar*hb+z*den*PeriGuadMar*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamMar*hb+z*den*PeriGuadLamMar*1*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamMar*hb+z*den*PeriLamMar*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamMar*hb+z*den*PeriLamMar*hb*theta)
            E[0:b2,n+1] = den*PMar1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadMar*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadMar*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadMar*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamMar*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamMar*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamMar*hb*S[g2:h2,n+1]
            C[:,n+1] = z* S[:,n+1]
            
        if d1<n<=e1: #April
            A = A1[:,3]
            B = BM[:,3]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PAp1*den*hb*0.46
            RHS[M] = -33.97*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0,e1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PAp1*hb+z*den*PAp1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadAp*hb+z*den*PeriBamGuadAp*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadAp*hb+z*den*PeriGuadAp*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadAp*hb+z*den*PeriGuadAp*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamAp*hb+z*den*PeriGuadLamAp*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamAp*hb+z*den*PeriLamAp*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamAp*hb+z*den*PeriLamAp*hb*theta)
            E[0:b2,n+1] = den*PAp1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadAp*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadAp*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadAp*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamAp*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamAp*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamAp*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if e1<n<=f1: #May
            A = A1[:,4]
            B = BM[:,4]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) +B
            RHS[0] = PMa1*den*hb*0.40
            RHS[M] = -423.26*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, f1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PMa1*hb+z*den*PMa1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadMa*hb+z*den*PeriBamGuadMa*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadMa*hb+z*den*PeriGuadMa*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadMa*hb+z*den*PeriGuadMa*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamMa*hb+z*den*PeriGuadLamMa*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamMa*hb+z*den*PeriLamMa*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamMa*hb+z*den*PeriLamMa*hb*theta)
            E[0:b2,n+1] = den*PMa1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadMa*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadMa*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadMa*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamMa*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamMa*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamMa*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if f1<n<=g1: #June
            A = A1[:,5] 
            B = BM[:,5]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJun1*den*hb*0.45
            RHS[M] = -23.46*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, g1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PJun1*hb+z*den*PJun1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadJun*hb+z*den*PeriBamGuadJun*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadJun*hb+z*den*PeriGuadJun*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadJun*hb+z*den*PeriGuadJun*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamJun*hb+z*den*PeriGuadLamJun*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamJun*hb+z*den*PeriLamJun*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamJun*hb+z*den*PeriLamJun*hb*theta)
            E[0:b2,n+1] = den*PJun1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadJun*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadJun*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadJun*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamJun*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamJun*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamJun*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if g1<n<=h1: #July
            A = A1[:,6]
            B = BM[:,6]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJul1*den*hb*0.45
            RHS[M] = -58.55*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, h1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PJul1*hb+z*den*PJul1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadJul*hb+z*den*PeriBamGuadJul*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadJul*hb+z*den*PeriGuadJul*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadJul*hb+z*den*PeriGuadJul*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamJul*hb+z*den*PeriGuadLamJul*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamJul*hb+z*den*PeriLamJul*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamJul*hb+z*den*PeriLamJul*hb*theta)
            E[0:b2,n+1] = den*PJul1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadJul*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadJul*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadJul*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamJul*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamJul*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamJul*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if h1<n<=i1: #August
            A = A1[:,7]
            B = BM[:,7]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PAu1*den*hb*0.37
            RHS[M] = -113.42*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, i1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PAu1*hb+z*den*PAu1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadAu*hb+z*den*PeriBamGuadAu*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadAu*hb+z*den*PeriGuadAu*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadAu*hb+z*den*PeriGuadAu*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamAu*hb+z*den*PeriGuadLamAu*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamAu*hb+z*den*PeriLamAu*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamAu*hb+z*den*PeriLamAu*hb*theta)
            E[0:b2,n+1] = den*PAu1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadAu*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadAu*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadAu*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamAu*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamAu*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamAu*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if i1<n<=j1: #September
            A = A1[:,8]
            B = BM[:,8]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PS1*den*hb*0.30
            RHS[M] = -106.74*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, j1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PS1*hb+z*den*PS1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadS*hb+z*den*PeriBamGuadS*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadS*hb+z*den*PeriGuadS*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadS*hb+z*den*PeriGuadS*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamS*hb+z*den*PeriGuadLamS*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamS*hb+z*den*PeriLamS*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamS*hb+z*den*PeriLamS*hb*theta)
            E[0:b2,n+1] = den*PS1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadS*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadS*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadS*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamS*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamS*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamS*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if j1<n<=k1: #October
            A = A1[:,9]
            B = BM[:,9]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PO1*den*hb*1.36
            RHS[M] = -380.80*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, k1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PO1*hb+z*den*PO1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadO*hb+z*den*PeriBamGuadO*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadO*hb+z*den*PeriGuadO*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadO*hb+z*den*PeriGuadO*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamO*hb+z*den*PeriGuadLamO*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamO*hb+z*den*PeriLamO*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamO*hb+z*den*PeriLamO*hb*theta)
            E[0:b2,n+1] = den*PO1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadO*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadO*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadO*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamO*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamO*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamO*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if k1<n<=l1: #November
            A = A1[:,10]
            B = BM[:,10]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PN1*den*hb*0.30
            RHS[M] = -55.08*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, l1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PN1*hb+z*den*PN1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadN*hb+z*den*PeriBamGuadN*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadN*hb+z*den*PeriGuadN*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadN*hb+z*den*PeriGuadN*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamN*hb+z*den*PeriGuadLamN*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamN*hb+z*den*PeriLamN*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamN*hb+z*den*PeriLamN*hb*theta)
            E[0:b2,n+1] = den*PN1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadN*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadN*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadN*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamN*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamN*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamN*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if l1<n<=m1: #December
            A = A1[:,11]
            B = BM[:,11]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PD1*den*hb*0.30
            RHS[M] = -52*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, m1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PD1*hb+z*den*PD1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadD*hb+z*den*PeriBamGuadD*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadD*hb+z*den*PeriGuadD*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadD*hb+z*den*PeriGuadD*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamD*hb+z*den*PeriGuadLamD*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamD*hb+z*den*PeriLamD*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamD*hb+z*den*PeriLamD*hb*theta)
            E[0:b2,n+1] = den*PD1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadD*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadD*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadD*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamD*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamD*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamD*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
            
    return   S, x, t, E

# %%
a2 = 0
b2 = 20
c2 = 58
d2 = 78
e2 = 101
f2 = 147
g2 = 171
h2 = 181

# %%
A1 = np.zeros((M+1,12))
A = np.zeros((M+1))

A1[0:20,0] = 228
A1[20:58,0] = 233
A1[58:78,0] = 238
A1[78:101,0] = 238
A1[101:147,0] = 239
A1[147:171,0] = 241

A1[0:20,1] = 290
A1[20:58,1] = 245
A1[58:78,1] = 200
A1[78:101,1] = 200
A1[101:147,1] = 172
A1[147:171,1] = 145

A1[0:20,2] = 182
A1[20:58,2] = 154
A1[58:78,2] = 126
A1[78:101,2] = 126
A1[101:147,2] = 182
A1[147:171,2] = 238

A1[0:20,3] = 150
A1[20:58,3] = 178
A1[58:78,3] = 207
A1[78:101,3] = 207
A1[101:147,3] = 245
A1[147:171,3] = 283

A1[0:20,4] = 189
A1[20:58,4] = 13
A1[58:78,4] = 84
A1[78:101,4] = 84
A1[101:147,4] = 226
A1[147:171,4] = 368

A1[0:20,5] = 163
A1[20:58,5] = 166
A1[58:78,5] = 169
A1[78:101,5] = 169
A1[101:147,5] = 182
A1[147:171,5] = 196

A1[0:20,6] = 173
A1[20:58,6] = 179
A1[58:78,6] = 185
A1[78:101,6] = 185
A1[101:147,6] = 197
A1[147:171,6] = 209

A1[0:20,7] = 254
A1[20:58,7] = 260
A1[58:78,7] = 266
A1[78:101,7] = 266
A1[101:147,7] = 369
A1[147:171,7] = 473

A1[0:20,8] = 212
A1[20:58,8] = 220
A1[58:78,8] = 228
A1[78:101,8] = 228
A1[101:147,8] = 319
A1[147:171,8] = 411

A1[0:20,9] = 221
A1[20:58,9] = 160
A1[58:78,9] = 99
A1[78:101,9] = 99
A1[101:147,9] = 185
A1[147:171,9] = 272

A1[0:20,10] = 254
A1[20:58,10] = 246
A1[58:78,10] = 238
A1[78:101,10] = 238
A1[101:147,10] = 348
A1[147:171,10] = 459

A1[0:20,11] = 228
A1[20:58,11] = 187
A1[58:78,11] = 147
A1[78:101,11] = 147
A1[101:147,11] = 260
A1[147:171,11] = 374


Q = np.zeros((M+1,N+1))

Q[a2:b2,0:b1] = 277.55 #Jan
Q[b2:c2,0:b1] = 242.25
Q[c2:d2,0:b1] = 206.96
Q[d2:e2,0:b1] = 206.96
Q[e2:f2,0:b1] = 115.51
Q[f2:g2,0:b1] = 24.06

Q[a2:b2,b1:c1] = 40.59 #Feb
Q[b2:c2,b1:c1] = 73.26
Q[c2:d2,b1:c1] = 105.94
Q[d2:e2,b1:c1] = 105.94
Q[e2:f2,b1:c1] = 210.47
Q[f2:g2,b1:c1] = 315.01

Q[a2:b2,c1:d1] = 220.22 #Mar
Q[b2:c2,c1:d1] = 117.05
Q[c2:d2,c1:d1] = 13.88
Q[d2:e2,c1:d1] = 13.88
Q[e2:f2,c1:d1] = 10.51
Q[f2:g2,c1:d1] = 7.14

Q[a2:b2,d1:e1] = 19.44 #April
Q[b2:c2,d1:e1] = 22.17
Q[c2:d2,d1:e1] = 24.90
Q[d2:e2,d1:e1] = 24.90
Q[e2:f2,d1:e1] = 29.43
Q[f2:g2,d1:e1] = 33.97

Q[a2:b2,e1:f1] = 65.98 # May
Q[b2:c2,e1:f1] = 76.46
Q[c2:d2,e1:f1] = 86.94
Q[d2:e2,e1:f1] = 86.94
Q[e2:f2,e1:f1] = 255.10
Q[f2:g2,e1:f1] = 423.26

Q[a2:b2,f1:g1] = 152.75 #June
Q[b2:c2,f1:g1] = 168.74
Q[c2:d2,f1:g1] = 184.73
Q[d2:e2,f1:g1] = 184.73
Q[e2:f2,f1:g1] = 104.10
Q[f2:g2,f1:g1] = 23.46

Q[a2:b2,g1:h1] = 24.21 #July
Q[b2:c2,g1:h1] = 38.88
Q[c2:d2,g1:h1] = 53.56
Q[d2:e2,g1:h1] = 53.56
Q[e2:f2,g1:h1] = 56.05
Q[f2:g2,g1:h1] = 58.55

Q[a2:b2,h1:i1] = 55.77 # Aug
Q[b2:c2,h1:i1] = 47.84
Q[c2:d2,h1:i1] = 39.90
Q[d2:e2,h1:i1] = 39.90
Q[e2:f2,h1:i1] = 76.66
Q[f2:g2,h1:i1] = 113.42

Q[a2:b2,i1:j1] = 65.69 # Sept
Q[b2:c2,i1:j1] = 64.76
Q[c2:d2,i1:j1] = 63.84
Q[d2:e2,i1:j1] = 63.84
Q[e2:f2,i1:j1] = 85.29
Q[f2:g2,i1:j1] = 106.74

Q[a2:b2,j1:k1] = 68.51 #October
Q[b2:c2,j1:k1] = 46.11
Q[c2:d2,j1:k1] = 23.71
Q[d2:e2,j1:k1] = 23.71
Q[e2:f2,j1:k1] = 202.26
Q[f2:g2,j1:k1] = 380.80

Q[a2:b2,k1:l1] = 30.42 #November
Q[b2:c2,k1:l1] = 128.20
Q[c2:d2,k1:l1] = 225.99
Q[d2:e2,k1:l1] = 225.99
Q[e2:f2,k1:l1] = 140.53
Q[f2:g2,k1:l1] = 55.08

Q[a2:b2,l1:m1] = 52 #December
Q[b2:c2,l1:m1] = 90
Q[c2:d2,l1:m1] = 128
Q[d2:e2,l1:m1] = 128
Q[e2:f2,l1:m1] = 90
Q[f2:g2,l1:m1] = 52

# %%
from scipy.integrate import quad
#Solving for matrices L1, L2, L3
T =  31104000
L = 8500
den = 0.01      #density of CIMW and CMW
theta = 1       #porosity
l = 50          #element distance
K = 1000        #dispersion coefficient K=diffusion+dispersitivity*fv
dt = 360        #time step size
dx = 50
N = int(round(T/dt))          #no. of time steps
M = int(round(L/dx))          #no. of nodes

#Solving for L1, let E=E^m/E (to be solve)
def integrand(x):
    return -(-1/l)*(1-x/l)
ans1, err = quad(integrand, 0, l)

def integrand(x):
    return -(-1/l)*(x/l)
ans2, err = quad(integrand, 0, l)

def integrand(x):
    return -(1/l)*(1-x/l)
ans3, err = quad(integrand, 0, l)

def integrand(x):
    return -(1/l)*(x/l)
ans4, err = quad(integrand, 0, l)

L1 = diags([ans3,(ans1+ans4),ans2], [-1,0,1], shape=(M+1, M+1)).toarray()
L1[0, 0] = ans1
L1[M, M] = ans4

#Solving QP1

def integrand(x):
    return (1-x/l)*(1-x/l)
ans5, err = quad(integrand, 0, l)

def integrand(x):
    return (1-x/l)*(x/l)
ans6, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(x/l)
ans7, err = quad(integrand, 0, l)

QP1_11 = ans5
QP1_12 = ans6
QP1_21 = ans6
QP1_22 = ans7

#QP1 Lump Matrix
QP11 = ans5+ans6
QP22 = (ans5+2*ans6+ans7)*np.ones(M+1)
QP21 = ans6+ans7
QP1 = np.zeros((M+1)**2).reshape(M+1, M+1)+np.diag(QP22, 0)
QP1[0, 0] = QP11
QP1[M, M] = QP21

#Solving for QP2

def integrand(x):
    return (1-x/l)*(-1/l)
ans8, err = quad(integrand, 0, l)

def integrand(x):
    return (1-x/l)*(1/l)
ans9, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(-1/l)
ans10, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(1/l)
ans11, err = quad(integrand, 0, l)

QP2_11 = ans8
QP2_12 = ans9
QP2_21 = ans10
QP2_22 = ans11

#Matrix QP
QP_11 = QP2_11/(ans5+2*ans6+ans7)
QP_12 = QP2_12/(ans5+2*ans6+ans7)
QP_21 = QP2_21/(ans5+2*ans6+ans7)
QP_22 = QP2_22/(ans5+2*ans6+ans7)
qp1 = (QP_11+QP_22)*np.ones(M+1)
qp2 = (QP_12)*np.ones(M)
qp3 = (QP_21)*np.ones(M)
QP = np.zeros((M+1)**2).reshape(M+1,M+1)+np.diag(qp1,0)+np.diag(qp2,1)++np.diag(qp3,-1)
QP[0,0] = QP2_11/QP11
QP[0,1] = QP2_12/QP11
QP[M,M] = QP2_21/QP21
QP[M,M] = QP2_22/QP21


#Solving for L2

def integrand(x):
    return (-1/l)*(1-x/l)
ans12, err = quad(integrand, 0, l)

def integrand(x):
    return (-1/l)*(x/l)
ans13, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(1-x/l)
ans14, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(x/l)
ans15, err = quad(integrand, 0, l)

L2 = diags([ans14,(ans12+ans15),ans13], [-1,0,1], shape=(M+1, M+1)).toarray()
L2[0,0] = ans12
L2[M,M] = ans15

#Solving for L3

def integrand(x):
    return (-1/l)*(-1/l)
ans16, err = quad(integrand, 0, l)

def integrand(x):
    return (-1/l)*(1/l)
ans17, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(-1/l)
ans18, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(1/l)
ans19, err = quad(integrand, 0, l)

L3 = diags([ans18,(ans16+ans19),ans17], [-1,0,1], shape=(M+1, M+1)).toarray()
L3[0,0] = ans16
L3[M,M] = ans19


#Solving for M

def integrand(x):
    return (1-x/l)*(1-x/l)
ans20, err = quad(integrand, 0, l)

def integrand(x):
    return (1-x/l)*(x/l)
ans21, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(1-x/l)
ans22, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(x/l)
ans23, err = quad(integrand, 0, l)

Z = diags([ans22,(ans20+ans23),ans21], [-1,0,1], shape=(M+1, M+1)).toarray()
Z[0, 0] = ans20
Z[M, M] = ans23


(S,x,t, E) = solver(T,dt,L1, L2, L3, Z)

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], [0.539, 0.42, 0.49, 0.46, 0.40, 0.45, 0.45, 0.37, 0.30, 1.36, 0.30, 0.30], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],[S[0,7200], S[0,14400], S[0,21600], S[0,28800], S[0,36000], S[0,43200], S[0,50400], S[0,57600], S[0,64800], S[0,72000], S[0,79200], S[0,86400]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("MTDS($g/m^3$)")
plt.title("TDS Bambang 2021, $K=1000$")
#plt.savefig('TDS March 2018, K=600, adjusted flow rate.png') 

plt.show()

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug","Sep", "Oct", "Nov", "Dec"], [0.479, 0.48, 0.47, 0.43, 0.49, 0.48, 0.42, 0.32, 0.33, 1.07, 0.29, 0.76], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],[S[72,7200], S[72,14400], S[72,21600], S[72,28800], S[72,36000], S[72,43200], S[72,50400], S[72,57600], S[72,64800], S[72,72000], S[72,79200], S[72,86400]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("TDS($g/m^3$)")
plt.title("TDS Guadalupe 2021")
#plt.savefig('TDS Guadalupe 2021.png') 

plt.show()

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], [0.444, 0.39, 0.49, 0.36, 0.55, 0.51, 0.48, 0.31, 0.31, 0.84, 0.32, 0.30], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], [S[170,7200], S[170,14400], S[170,21600], S[170,28800], S[170,36000], S[170,43200], S[170,50400], S[170,57600], S[170,64800], S[170,72000], S[170,79200], S[170,86400]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("TDS($g/m^3$)")
plt.title("TDS Lambingan 2021")
plt.savefig('TDS Lambingan 2021.png') 

plt.show()
