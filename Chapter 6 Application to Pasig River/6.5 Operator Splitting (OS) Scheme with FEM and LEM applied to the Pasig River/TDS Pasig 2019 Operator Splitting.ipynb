# %%
from scipy.sparse import diags #linalg
from scipy.linalg import solve
import numpy as np
from numpy.linalg import inv, det
from matplotlib import pyplot as plt

# %%
a1 = 0 
b1 = 7200
c1 = 2*b1
d1 = 3*b1
e1 = 4*b1
f1 = 5*b1
g1 = 6*b1
h1 = 7*b1
i1 = 8*b1
j1 = 9*b1
k1 = 10*b1
l1 = 11*b1
m1 = 12*b1
n1 = 13*b1
o1 = 14*b1
p1 = 15*b1
q1 = 16*b1
r1 = 17*b1

z = 0.01

# %%
#Depth per month of the sources
J1 = 3.5
J2 = 4.3
J3 = 0.73
J4 = 0.37
J5 = 0.7
J6 = 0.9

F1 = 4.23
F2 = 3.93
F3 = 1.07
F4 = 0.37
F5 = 0.97
F6 = 0.77

Mar1 = 3.3
Mar2 = 2.77 
Mar3 = 0.4
Mar4 = 0.37
Mar5 = 1.07
Mar6 = 1.57

Ap1 = 4.43
Ap2 = 3.07
Ap3 = 0.4
Ap4 = 0.2
Ap5 = 0.6
Ap6 = 0.6

Ma1 = 2.9
Ma2 = 3.07
Ma3 = 0.53
Ma4 = 0.45
Ma5 = 0.67
Ma6 = 0.37

Jun1 = 4.17
Jun2 = 3.97
Jun3 = 0.83
Jun4 = 0.53
Jun5 = 0.77
Jun6 = 0.67

Jul1 = 4.83
Jul2 = 3.57
Jul3 = 1.37
Jul4 = 0.7
Jul5 = 1.33
Jul6 = 0.43

Au1 = 2.6
Au2 = 2.4
Au3 = 1.07
Au4 = 0.67
Au5 = 1.7
Au6 = 0.9

S1 = 2.87
S2 = 3.1
S3 = 0.7
S4 = 0.83
S5 = 1.17
S6 = 0.73

O1 = 2.7
O2 = 2.6
O3 = 0.8
O4 = 0.53
O5 = 1.3
O6 = 0.73

N1 = 3.43
N2 = 3.3
N3 = 0.63
N4 = 0.53
N5 = 0.8
N6 = 0.6

# %%
#Wetted Perimeter
PJ1 = 2*J1 + 65
PJ2 = 2*J2 + 53
PJ3 = 2*J3 + 7
PJ4 = 2*J4 + 7
PJ5 = 2*J5 + 9
PJ6 = 2*J6 + 7

PF1 = 2*F1 + 65
PF2 = 2*F2 + 53
PF3 = 2*F3 + 7
PF4 = 2*F4 + 7
PF5 = 2*F5 + 9
PF6 = 2*F6 + 7

PMar1 = 2*Mar1 +  65
PMar2 = 2*Mar2 +  53
PMar3 = 2*Mar3 +  7
PMar4 = 2*Mar4 +  7
PMar5 = 2*Mar5 +  9
PMar6 = 2*Mar6 +  7

PAp1 = 2*Ap1 + 65
PAp2 = 2*Ap2 + 53
PAp3 = 2*Ap3 + 7
PAp4 = 2*Ap4 + 7
PAp5 = 2*Ap5 + 9
PAp6 = 2*Ap6 + 7

PMa1 = 2*Ma1 + 65
PMa2 = 2*Ma2 + 53
PMa3 = 2*Ma3 + 7
PMa4 = 2*Ma4 + 7
PMa5 = 2*Ma5 + 9
PMa6 = 2*Ma6 + 7

PJun1 = 2*Jun1 + 65
PJun2 = 2*Jun2 + 53
PJun3 = 2*Jun3 + 7
PJun4 = 2*Jun4 + 7
PJun5 = 2*Jun5 + 9
PJun6 = 2*Jun6 + 7

PJul1 = 2*Jul1 + 65
PJul2 = 2*Jul2 + 53
PJul3 = 2*Jul3 + 7
PJul4 = 2*Jul4 + 7
PJul5 = 2*Jul5 + 9
PJul6 = 2*Jul6 + 7

PAu1 = 2*Au1 + 65
PAu2 = 2*Au2 + 53
PAu3 = 2*Au3 + 7
PAu4 = 2*Au4 + 7
PAu5 = 2*Au5 + 9
PAu6 = 2*Au6 + 7

PS1 = 2*S1 + 65
PS2 = 2*S2 + 53
PS3 = 2*S3 + 7
PS4 = 2*S4 + 7
PS5 = 2*S5 + 9
PS6 = 2*S6 + 7

PO1 = 2*O1 + 65
PO2 = 2*O2 + 53
PO3 = 2*O3 + 7
PO4 = 2*O4 + 7
PO5 = 2*O5 + 9
PO6 = 2*O6 + 7

PN1 = 2*N1 + 65
PN2 = 2*N2 + 53
PN3 = 2*N3 + 7
PN4 = 2*N4 + 7
PN5 = 2*N5 + 9
PN6 = 2*N6 + 7

# %%
#depth and wetted perimeter of Guadalupe and Lambingan
DepthBamGuadJ = 2.77
DepthBamGuadF = 3.77
DepthBamGuadMar = 3.14
DepthBamGuadAp = 3.38
DepthBamGuadMa = 2.05
DepthBamGuadJun = 3.39
DepthBamGuadJul = 4.00
DepthBamGuadAu = 2.77
DepthBamGuadS = 2.94
DepthBamGuadO = 2.34
DepthBamGuadN = 2.73
#DepthBamGuadD = 


DepthGuadJ = 2.03
DepthGuadF = 3.30
DepthGuadMar = 2.97
DepthGuadAp = 2.33
DepthGuadMa = 1.20
DepthGuadJun = 2.60
DepthGuadJul = 3.17
DepthGuadAu = 2.93
DepthGuadS = 3.00
DepthGuadO = 1.97
DepthGuadN = 2.03
#DepthGuadD = 

DepthGuadLamJ = 2.85
DepthGuadLamF = 2.99
DepthGuadLamMar = 3.12
DepthGuadLamAp = 2.78
DepthGuadLamMa = 2.10
DepthGuadLamJun = 3.12
DepthGuadLamJul = 3.59
DepthGuadLamAu = 3.10
DepthGuadLamS = 3.12
DepthGuadLamO = 2.65
DepthGuadLamN = 2.70
#DepthGuadLamD = 

DepthLamJ = 3.67
DepthLamF = 2.67
DepthLamMar = 3.27
DepthLamAp = 3.23
DepthLamMa = 3.00
DepthLamJun = 3.63
DepthLamJul = 4.00
DepthLamAu = 3.27
DepthLamS = 3.23
DepthLamO = 3.33
DepthLamN = 3.37
#DepthLamD = 

PeriBamGuadJ = 2*DepthBamGuadJ + 70
PeriBamGuadF = 2*DepthBamGuadF + 70
PeriBamGuadMar = 2*DepthBamGuadMar + 70
PeriBamGuadAp = 2*DepthBamGuadAp + 70
PeriBamGuadMa = 2*DepthBamGuadMa + 70
PeriBamGuadJun = 2*DepthBamGuadJun + 70
PeriBamGuadJul = 2*DepthBamGuadJul + 70
PeriBamGuadAu = 2*DepthBamGuadAu + 70
PeriBamGuadS = 2*DepthBamGuadS + 70
PeriBamGuadO = 2*DepthBamGuadO + 70
PeriBamGuadN = 2*DepthBamGuadN + 70
#PeriBamGuadD = 2*DepthBamGuadD + 70

PeriGuadJ = 2*DepthGuadJ + 76
PeriGuadF =  2*DepthGuadF + 76
PeriGuadMar =  2*DepthGuadMar + 76
PeriGuadAp =  2*DepthGuadAp + 76
PeriGuadMa =  2*DepthGuadMa + 76
PeriGuadJun =  2*DepthGuadJun + 76
PeriGuadJul =  2*DepthGuadJul + 76
PeriGuadAu =  2*DepthGuadAu + 76
PeriGuadS =  2*DepthGuadS + 76
PeriGuadO =  2*DepthGuadO + 76
PeriGuadN =  2*DepthGuadN + 76

PeriGuadLamJ = 2*DepthGuadLamJ + 80
PeriGuadLamF = 2*DepthGuadLamF + 80
PeriGuadLamMar = 2*DepthGuadLamMar + 80
PeriGuadLamAp = 2*DepthGuadLamAp + 80
PeriGuadLamMa = 2*DepthGuadLamMa + 80
PeriGuadLamJun = 2*DepthGuadLamJun + 80
PeriGuadLamJul = 2*DepthGuadLamJul + 80
PeriGuadLamAu = 2*DepthGuadLamAu + 80
PeriGuadLamS = 2*DepthGuadLamS + 80
PeriGuadLamO = 2*DepthGuadLamO + 80
PeriGuadLamN = 2*DepthGuadLamN + 80

PeriLamJ = 2*DepthLamJ + 85
PeriLamF = 2*DepthLamF + 85
PeriLamMar = 2*DepthLamMar + 85
PeriLamAp = 2*DepthLamAp + 85
PeriLamMa = 2*DepthLamMa + 85
PeriLamJun = 2*DepthLamJun + 85
PeriLamJul = 2*DepthLamJul + 85
PeriLamAu = 2*DepthLamAu + 85
PeriLamS = 2*DepthLamS + 85
PeriLamO = 2*DepthLamO + 85
PeriLamN = 2*DepthLamN + 85

hb = 1

# %%
def solver(T,dt,L1, L2, Z):
    N = int(round(T/dt))
    t = np.linspace(0,T,N+1) #time discrete
    M = int(round(L/dx))
    x = np.linspace(0,L,M+1) #space discrete
    E = np.zeros((M+1,N+1))
    S = np.zeros((M+1,N+1))
    C = np.zeros((M+1,N+1))
    PPX = np.zeros((M+1))
    Em = np.zeros((M+1,N+1))
    BM = np.zeros((M+1,11))
    Bi = np.zeros((M+1))
    RHS = np.zeros((M+1))
    B = np.zeros((M+1))
    A = np.zeros((M+1))
    QW = np.zeros((M+1,11))
    
    #initial conditions
    S[0,a1:b1] = 0.27
    S[0,b1:c1] = 0.27
    S[0,c1:d1] = 0.31
    S[0,d1:e1] = 0.50
    S[0,e1:f1] = 6.54
    S[0,f1:g1] = 4.33
    S[0,g1:h1] = 0.46
    S[0,h1:i1] = 0.49
    S[0,i1:j1] = 1.74
    S[0,j1:k1] = 0.46
    S[0,k1:l1] = 0.26
    C[0,a1:b1] = z*S[0,a1:b1]
    C[0,b1:c1] = z*S[0,b1:c1]
    C[0,c1:d1] = z*S[0,c1:d1]
    C[0,d1:e1] = z*S[0,d1:e1]
    C[0,e1:f1] = z*S[0,e1:f1]
    C[0,f1:g1] = z*S[0,f1:g1]
    C[0,g1:h1] = z*S[0,g1:h1]
    C[0,h1:i1] = z*S[0,h1:i1]
    C[0,i1:j1] = z*S[0,i1:j1]
    C[0,j1:k1] = z*S[0,j1:k1]
    C[0,k1:l1] = z*S[0,k1:l1]
    E[0,a1:b1] = PJ1*den*hb*S[0,a1:b1]
    E[0,b1:c1] = PF1*den*hb*S[0,b1:c1]
    E[0,c1:d1] = PMar1*den*hb*S[0,c1:d1]
    E[0,d1:e1] = PAp1*den*hb*S[0,d1:e1]
    E[0,e1:f1] = PMa1*den*hb*S[0,e1:f1]
    E[0,f1:g1] = PJun1*den*hb*S[0,f1:g1]
    E[0,g1:h1] = PJul1*den*hb*S[0,g1:h1]
    E[0,h1:i1] = PAu1*den*hb*S[0,h1:i1]
    E[0,i1:j1] = PS1*den*S1*S[0,i1:j1]
    E[0,j1:k1] = PO1*den*hb*S[0,j1:k1]
    E[0,k1:l1] = PN1*den*hb*S[0,k1:l1]
    
    #Flow Rate Boundary
    QW[0,0] = 25.03
    QW[24,0] = 22.79
    QW[66,0] = 2.61
    QW[72,0] = 0.13
    QW[88,0] = 2.08
    QW[148,0] = 0.25
    
    QW[0,1] = 250.20
    QW[24,1] = 6.25
    QW[66,1] = 2.17
    QW[72,1] = 0.08
    QW[88,1] = 0.35
    QW[148,1] = 0.54
    
    QW[0,2] = 98.67
    QW[24,2] = 10.28
    QW[66,2] = 0.36
    QW[72,2] = 0.03
    QW[88,2] = 0.10
    QW[148,2] = 0.44
    
    QW[0,3] = 0.00
    QW[24,3] = 6.51
    QW[66,3] = 0.08
    QW[72,3] = 0.21
    QW[88,3] = 0.11
    QW[148,3] = 0.42
    
    QW[0,4] = 67.86
    QW[24,4] = 9.76
    QW[66,4] = 0.74
    QW[72,4] = 0.28
    QW[88,4] = 0.42
    QW[148,4] = 0.31
    
    QW[0,5] = 146.37
    QW[24,5] = 10.52
    QW[66,5] = 1.05
    QW[72,5] = 0.11
    QW[88,5] = 0.28
    QW[148,5] = 0.09
    
    QW[0,6] = 185.23
    QW[24,6] = 11.35
    QW[66,6] = 5.18
    QW[72,6] = 0.25
    QW[88,6] = 1.80
    QW[148,6] = 0.36
    
    QW[0,7] = 13.52
    QW[24,7] = 5.09
    QW[66,7] = 1.05
    QW[72,7] = 0.42
    QW[88,7] = 1.22
    QW[148,7] = 0.57
    
    QW[0,8] = 136.18
    QW[24,8] = 32.86
    QW[66,8] = 3.43
    QW[72,8] = 0.52
    QW[88,8] = 4.00
    QW[148,8] = 0.10
    
    QW[0,9] = 184.28
    QW[24,9] = 16.54
    QW[66,9] = 3.25
    QW[72,9] = 0.48
    QW[88,9] = 1.29
    QW[148,9] = 0.82
    
    QW[0,10] = 196.20
    QW[24,10] = 27.98
    QW[66,10] = 2.60
    QW[72,10] = 0.48
    QW[88,10] = 0.00
    QW[148,10] = 0.76
   
    #boundary/sources
    BM[0,0] = QW[0,0]*(PJ1*den*hb*0.27) 
    BM[24,0] = QW[24,0]*(PJ2*den*J2*0.34)
    BM[66,0] = QW[66,0]*(PJ3*den*J3*0.36)
    BM[72,0] = QW[72,0]*(PJ4*den*J4*0.48)
    BM[88,0] = QW[88,0]*(PJ5*den*J5*0.47)
    BM[148,0] = QW[148,0]*(PJ6*den*J6*0.47)
    
    BM[0,1] = QW[0,1]*(PF1*den*hb*0.27)  
    BM[24,1] = QW[24,1]*(PF2*den*F2*0.42+z*PF2*F2*den*theta*0.42)
    BM[66,1] = QW[66,1]*(PF3*den*F3*0.38+z*PF3*F3*den*theta*0.38)
    BM[72,1] = QW[72,1]*(PF4*den*F4*0.45+z*PF4*F4*den*theta*0.45)
    BM[88,1] = QW[88,1]*(PF5*den*F5*0.50+z*PF5*F5*den*theta*0.50)
    BM[148,1] = QW[148,1]*(PF6*den*F6*0.56+z*PF6*F6*den*theta*0.56)
    
    BM[0,2] = QW[0,2]*(PMar1*den*hb*0.31)  
    BM[24,2] = QW[24,2]*(PMar2*den*Mar2*0.51+z*PMar2*den*Mar2*theta*0.51)
    BM[66,2] = QW[66,2]*(PMar3*den*Mar3*0.48+z*PMar3*den*Mar3*theta*0.48)
    BM[72,2] = QW[72,2]*(PMar4*den*Mar4*0.57+z*PMar4*den*Mar4*theta*0.57)
    BM[88,2] = QW[88,2]*(PMar5*den*Mar5*0.55+z*PMar5*den*Mar5*theta*0.55)
    BM[148,2] = QW[148,2]*(PMar6*den*Mar6*0.49+z*PMar6*den*Mar6*theta*0.49)
    
    BM[0,3] = QW[0,3]*E[0,e1-1]  
    BM[24,3] = QW[24,3]*(PAp2*den*Ap2*0.98+z*PAp2*den*Ap2*theta*0.98)
    BM[66,3] = QW[66,3]*(PAp3*den*Ap3*0.37+z*PAp3*den*Ap3*theta*0.37)
    BM[72,3] = QW[72,3]*(PAp4*den*Ap4*0.51+z*PAp4*den*Ap4*theta*0.51)
    BM[88,3] = QW[88,3]*(PAp5*den*Ap5*0.51+z*PAp5*den*Ap5*theta*0.51)
    BM[148,3] = QW[148,3]*(PAp6*den*Ap6*0.57+z*PAp6*den*Ap6*theta*0.57)
    
    BM[0,4] = QW[0,4]*E[0,f1-1]  
    BM[24,4] = QW[24,4]*(PMa2*den*Ma2*4.45+z*PMa2*den*Ma2*theta*4.45)
    BM[66,4] = QW[66,4]*(PMa3*den*Ma3*0.35+z*PMa3*den*Ma3*theta*0.35)
    BM[72,4] = QW[72,4]*(PMa4*den*Ma4*0.5+z*PMa4*den*Ma4*theta*0.5)
    BM[88,4] = QW[88,4]*(PMa5*den*Ma5*0.80+z*PMa5*den*Ma5*theta*0.80)
    BM[148,4] = QW[148,4]*(PMa6*den*Ma6*0.52+z*PMa6*den*Ma6*theta*0.52)
    
    BM[0,5] = QW[0,5]*E[0,g1-1]  
    BM[24,5] = QW[24,5]*(PJun2*den*Jun2*3.58+z*PJun2*den*Jun2*theta*3.58)
    BM[66,5] = QW[66,5]*(PJun3*den*Jun3*4.98+z*PJun3*den*Jun3*theta*4.98)
    BM[72,5] = QW[72,5]*(PJun4*den*Jun4*0.92+z*PJun4*den*Jun4*theta*0.92)
    BM[88,5] = QW[88,5]*(PJun5*den*Jun5*2+z*PJun5*den*Jun5*theta*2)
    BM[148,5] = QW[148,5]*(PJun6*den*Jun6*0.51+z*PJun6*den*Jun6*theta*0.51)
    
    BM[0,6] = QW[0,6]*E[0,h1-1]  
    BM[24,6] = QW[24,6]*(PJul2*den*Jul2*0.37+z*PJul2*den*Jul2*theta*0.37)
    BM[66,6] = QW[66,6]*(PJul3*den*Jul3*0.25+z*PJul3*den*Jul3*theta*0.25)
    BM[72,6] = QW[72,6]*(PJul4*den*Jul4*0.61+z*PJul4*den*Jul4*theta*0.61)
    BM[88,6] = QW[88,6]*(PJul5*den*Jul5*0.44+z*PJul5*den*Jul5*theta*0.44)
    BM[148,6] = QW[148,6]*(PJul6*den*Jul6*0.37+z*PJul6*den*Jul6*theta*0.37)
    
    BM[0,7] = QW[0,7]*E[0,i1-1]  
    BM[24,7] = QW[24,7]*(PAu2*den*Au2*0.21+z*PAu2*den*Au2*theta*0.21)
    BM[66,7] = QW[66,7]*(PAu3*den*Au3*0.34+z*PAu3*den*Au3*theta*0.34)
    BM[72,7] = QW[72,7]*(PAu4*den*Au4*0.48+z*PAu4*den*Au4*theta*0.48)
    BM[88,7] = QW[88,7]*(PAu5*den*Au5*0.43+z*PAu5*den*Au5*theta*0.43)
    BM[148,7] = QW[148,7]*(PAu6*den*Au6*0.48+z*PAu6*den*Au6*theta*0.48) 
   
    BM[0,8] = QW[0,8]*E[0,j1-1]  
    BM[24,8] = QW[24,8]*(PS2*den*S2*0+z*PS2*den*S2*theta*0)
    BM[66,8] = QW[66,8]*(PS3*den*S3*0+z*PS3*den*S3*theta*0)
    BM[72,8] = QW[72,8]*(PS4*den*S4*0+z*PS4*den*S4*theta*0)
    BM[88,8] = QW[88,8]*(PS5*den*S5*0+z*PS5*den*S5*theta*0)
    BM[148,8] = QW[148,8]*(PS6*den*S6*1.61+z*PS6*den*S6*theta*1.61)
    
    BM[0,9] = QW[0,9]*E[0,k1-1]
    BM[24,9] = QW[24,9]*(PO2*den*O2*0.30+z*PO2*den*O2*theta*0.30)
    BM[66,9] = QW[66,9]*(PO3*den*O3*0.36+z*PO3*den*O3*theta*0.36)
    BM[72,9] = QW[72,9]*(PO4*den*O4*0.49+z*PO4*den*O4*theta*0.49)
    BM[88,9] = QW[88,9]*(PO5*den*O5*0.46+z*PO5*den*O5*theta*0.46)
    BM[148,9] = QW[148,9]*(PO6*den*O6*0.46+z*PO6*den*O6*theta*0.46)
    
    BM[0,10] = QW[0,10]*E[0,l1-1]  
    BM[24,10] = QW[24,10]*(PN2*den*N2*0.01+z*PN2*den*N2*theta*0.01)
    BM[66,10] = QW[66,10]*(PN3*den*N3*0.41+z*PN3*den*N3*theta*0.41)
    BM[72,10] = QW[72,10]*(PN4*den*N4*0.50+z*PN4*den*N4*theta*0.50)
    BM[88,10] = QW[88,10]*(PN5*den*N5*0.54+z*PN5*den*N5*theta*0.54)
    BM[148,10] = QW[148,10]*(PN6*den*N6*0.68+z*PN6*den*N6*theta*0.68)
    
    
    #special time step at n=0
    A = A1[:,0]
    B = BM[:,0]
    L11 = np.multiply(L1,Q[0:M+1,0])
    L22 = np.multiply(L2,A)
    Z1 = np.multiply(Z,A)
    M1 = Z1 / dt +  (L11 + L22*K)
    E[:,1] = np.linalg.solve(M1, B)
    Em[:,1] = E[:,1] + C[:,0]
    S[0,1] = S[0,a1]
    S[1:b2,1] = Em[1:b2,1] / (den*PJ1*hb+z*den*PJ1*hb*theta)
    S[b2:c2,1] = Em[b2:c2,1] / (den*PeriBamGuadJ*hb+z*den*PeriBamGuadJ*hb*theta)
    S[c2:d2,1] = Em[c2:d2,1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
    S[d2:e2,1] = Em[d2:e2,1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
    S[e2:f2,1] = Em[e2:f2,1] / (den*PeriGuadLamJ*hb+z*den*PeriGuadLamJ*hb*theta)
    S[f2:g2,1] = Em[f2:g2,1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
    S[g2:h2,1] = Em[g2:h2,1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
    E[0:b2,1] = den*PJ1*hb*S[0:b2,1]
    E[b2:c2,1] = den*PeriBamGuadJ*hb*S[b2:c2,1]
    E[c2:d2,1] = den*PeriGuadJ*hb*S[c2:d2,1]
    E[d2:e2,1] = den*PeriGuadJ*hb*S[d2:e2,1]
    E[e2:f2,1] = den*PeriGuadLamJ*hb*S[e2:f2,1]
    E[f2:g2,1] = den*PeriLamJ*hb*S[f2:g2,1]
    E[g2:h2,1] = den*PeriLamJ*hb*S[g2:h2,1]
    C[:,1] = z*S[:,1]
    
    
    
    for n in range(1,N):
        #update all matrices
        if n<=b1: #January
            A = A1[:,0]
            B = BM[:,0]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJ1*den*hb*0.27
            RHS[M] = -193.41*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0,a1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PJ1*hb+z*den*PJ1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadJ*hb+z*den*PeriBamGuadJ*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamJ*hb+z*den*PeriGuadLamJ*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
            E[0:b2,n+1] = den*PJ1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadJ*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadJ*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadJ*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamJ*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamJ*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamJ*hb*S[g2:h2,n+1]
            C[:,n+1] = z*S[:,n+1]
            
        if b1<n<=c1: #February
            A = A1[:,1]
            B = BM[:,1]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJ1*den*hb*0.27
            RHS[M] = -193.41*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = Em[0,n+1] / (den*PF1*hb)
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PF1*hb+z*den*PF1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadF*hb+z*den*PeriBamGuadF*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadF*hb+z*den*PeriGuadF*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadF*hb+z*den*PeriGuadF*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamF*hb+z*den*PeriGuadLamF*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamF*hb+z*den*PeriLamF*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamF*hb+z*den*PeriLamF*hb*theta)
            E[0:b2,n+1] = den*PF1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadF*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadF*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadF*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamF*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamF*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamF*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if c1<n<=d1: #March
            A = A1[:,2]
            B = BM[:,2]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PMar1*den*hb*0.31
            RHS[M] = -22.24*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = Em[0,n+1] / (den*PMar1*hb)
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PMar1*hb+z*den*PMar1*1*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadMar*hb+z*den*PeriBamGuadMar*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadMar*hb+z*den*PeriGuadMar*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadMar*hb+z*den*PeriGuadMar*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamMar*hb+z*den*PeriGuadLamMar*1*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamMar*hb+z*den*PeriLamMar*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamMar*hb+z*den*PeriLamMar*hb*theta)
            E[0:b2,n+1] = den*PMar1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadMar*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadMar*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadMar*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamMar*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamMar*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamMar*hb*S[g2:h2,n+1]
            C[:,n+1] = z* S[:,n+1]
            
        if d1<n<=e1: #April
            A = A1[:,3]
            B = BM[:,3]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PAp1*den*hb*0.50
            RHS[M] = -87.86*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = Em[0,n+1] / (den*PAp1*hb)
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PAp1*hb+z*den*PAp1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadAp*hb+z*den*PeriBamGuadAp*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadAp*hb+z*den*PeriGuadAp*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadAp*hb+z*den*PeriGuadAp*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamAp*hb+z*den*PeriGuadLamAp*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamAp*hb+z*den*PeriLamAp*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamAp*hb+z*den*PeriLamAp*hb*theta)
            E[0:b2,n+1] = den*PAp1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadAp*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadAp*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadAp*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamAp*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamAp*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamAp*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if e1<n<=f1: #May
            A = A1[:,4]
            B = BM[:,4]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) +B
            RHS[0] = PMa1*den*hb*6.54
            RHS[M] = -12.75*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, f1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PMa1*hb+z*den*PMa1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadMa*hb+z*den*PeriBamGuadMa*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadMa*hb+z*den*PeriGuadMa*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadMa*hb+z*den*PeriGuadMa*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamMa*hb+z*den*PeriGuadLamMa*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamMa*hb+z*den*PeriLamMa*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamMa*hb+z*den*PeriLamMa*hb*theta)
            E[0:b2,n+1] = den*PMa1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadMa*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadMa*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadMa*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamMa*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamMa*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamMa*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if f1<n<=g1: #June
            A = A1[:,5] 
            B = BM[:,5]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJun1*den*hb*4.33
            RHS[M] = -154.28*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, g1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PJun1*hb+z*den*PJun1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadJun*hb+z*den*PeriBamGuadJun*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadJun*hb+z*den*PeriGuadJun*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadJun*hb+z*den*PeriGuadJun*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamJun*hb+z*den*PeriGuadLamJun*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamJun*hb+z*den*PeriLamJun*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamJun*hb+z*den*PeriLamJun*hb*theta)
            E[0:b2,n+1] = den*PJun1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadJun*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadJun*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadJun*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamJun*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamJun*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamJun*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if g1<n<=h1: #July
            A = A1[:,6]
            B = BM[:,6]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PJul1*den*hb*0.46
            RHS[M] = -10.20*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, h1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PJul1*hb+z*den*PJul1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadJul*hb+z*den*PeriBamGuadJul*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadJul*hb+z*den*PeriGuadJul*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadJul*hb+z*den*PeriGuadJul*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamJul*hb+z*den*PeriGuadLamJul*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamJul*hb+z*den*PeriLamJul*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamJul*hb+z*den*PeriLamJul*hb*theta)
            E[0:b2,n+1] = den*PJul1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadJul*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadJul*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadJul*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamJul*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamJul*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamJul*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if h1<n<=i1: #August
            A = A1[:,7]
            B = BM[:,7]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PAu1*den*hb*0.49
            RHS[M] = -141.75*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, i1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PAu1*hb+z*den*PAu1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadAu*hb+z*den*PeriBamGuadAu*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadAu*hb+z*den*PeriGuadAu*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadAu*hb+z*den*PeriGuadAu*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamAu*hb+z*den*PeriGuadLamAu*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamAu*hb+z*den*PeriLamAu*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamAu*hb+z*den*PeriLamAu*hb*theta)
            E[0:b2,n+1] = den*PAu1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadAu*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadAu*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadAu*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamAu*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamAu*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamAu*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if i1<n<=j1: #September
            A = A1[:,8]
            B = BM[:,8]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PS1*den*hb*1.74
            RHS[M] = -178.46*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS) 
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, j1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PS1*hb+z*den*PS1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadS*hb+z*den*PeriBamGuadS*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadS*hb+z*den*PeriGuadS*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadS*hb+z*den*PeriGuadS*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamS*hb+z*den*PeriGuadLamS*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamS*hb+z*den*PeriLamS*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamS*hb+z*den*PeriLamS*hb*theta)
            E[0:b2,n+1] = den*PS1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadS*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadS*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadS*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamS*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamS*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamS*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if j1<n<=k1: #October
            A = A1[:,9]
            B = BM[:,9]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PO1*den*hb*0.46
            RHS[M] = -186.81*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, k1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PO1*hb+z*den*PO1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadO*hb+z*den*PeriBamGuadO*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadO*hb+z*den*PeriGuadO*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadO*hb+z*den*PeriGuadO*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamO*hb+z*den*PeriGuadLamO*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamO*hb+z*den*PeriLamO*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamO*hb+z*den*PeriLamO*hb*theta)
            E[0:b2,n+1] = den*PO1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadO*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadO*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadO*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamO*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamO*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamO*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if k1<n<=l1: #November
            A = A1[:,10]
            B = BM[:,10]
            L11 = np.multiply(L1,Q[0:M+1,n])
            L22 = np.multiply(L2,A)
            Z1 = np.multiply(Z,A)
            M1 = Z1 / dt + (L11 + L22*K)
            M2 = Z1 / dt - (L11 + L22*K)
            RHS[:] = M2.dot(E[:,n]) + B
            RHS[0] = PN1*den*hb*0.26
            RHS[M] = -174.73*E[M,n]
            M1[0,0] = 1
            M1[0,1] = 0
            E[:,n+1] = np.linalg.solve(M1, RHS)
            Em[:,n+1] = E[:,n+1] + C[:,n]
            S[0,n+1] = S[0, l1-1]
            S[1:b2,n+1] = Em[1:b2,n+1] / (den*PN1*hb+z*den*PN1*hb*theta)
            S[b2:c2,n+1] = Em[b2:c2,n+1] / (den*PeriBamGuadN*hb+z*den*PeriBamGuadN*hb*theta)
            S[c2:d2,n+1] = Em[c2:d2,n+1] / (den*PeriGuadN*hb+z*den*PeriGuadN*hb*theta)
            S[d2:e2,n+1] = Em[d2:e2,n+1] / (den*PeriGuadN*hb+z*den*PeriGuadN*hb*theta)
            S[e2:f2,n+1] = Em[e2:f2,n+1] / (den*PeriGuadLamN*hb+z*den*PeriGuadLamN*hb*theta)
            S[f2:g2,n+1] = Em[f2:g2,n+1] / (den*PeriLamN*hb+z*den*PeriLamN*hb*theta)
            S[g2:h2,n+1] = Em[g2:h2,n+1] / (den*PeriLamN*hb+z*den*PeriLamN*hb*theta)
            E[0:b2,n+1] = den*PN1*hb*S[0:b2,n+1]
            E[b2:c2,n+1] = den*PeriBamGuadN*hb*S[b2:c2,n+1]
            E[c2:d2,n+1] = den*PeriGuadN*hb*S[c2:d2,n+1]
            E[d2:e2,n+1] = den*PeriGuadN*hb*S[d2:e2,n+1]
            E[e2:f2,n+1] = den*PeriGuadLamN*hb*S[e2:f2,n+1]
            E[f2:g2,n+1] = den*PeriLamN*hb*S[f2:g2,n+1]
            E[g2:h2,n+1] = den*PeriLamN*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
            
    return   S, x, t, E

# %%
a2 = 0
b2 = 20
c2 = 58
d2 = 78
e2 = 101
f2 = 147
g2 = 171
h2 = 181

# %%
A1 = np.zeros((M+1,12))
A = np.zeros((M+1))

A1[0:20,0] = 228
A1[20:58,0] = 191
A1[58:78,0] = 154
A1[78:101,0] = 154
A1[101:147,0] = 233
A1[147:171,0] = 312

A1[0:20,1] = 275
A1[20:58,1] = 263
A1[58:78,1] = 251
A1[78:101,1] = 251
A1[101:147,1] = 239
A1[147:171,1] = 227

A1[0:20,2] = 215
A1[20:58,2] = 220
A1[58:78,2] = 226
A1[78:101,2] = 226
A1[101:147,2] = 252
A1[147:171,2] = 278

A1[0:20,3] = 288
A1[20:58,3] = 233
A1[58:78,3] = 177
A1[78:101,3] = 177
A1[101:147,3] = 226
A1[147:171,3] = 275

A1[0:20,4] = 189
A1[20:58,4] = 140
A1[58:78,4] = 91
A1[78:101,4] = 91
A1[101:147,4] = 173
A1[147:171,4] = 255

A1[0:20,5] = 271
A1[20:58,5] = 234
A1[58:78,5] = 198
A1[78:101,5] = 198
A1[101:147,5] = 253
A1[147:171,5] = 309

A1[0:20,6] = 314
A1[20:58,6] = 277
A1[58:78,6] = 241
A1[78:101,6] = 241
A1[101:147,6] = 290
A1[147:171,6] = 340

A1[0:20,7] = 169
A1[20:58,7] = 196
A1[58:78,7] = 223
A1[78:101,7] = 223
A1[101:147,7] = 250
A1[147:171,7] = 278

A1[0:20,8] = 187
A1[20:58,8] = 207
A1[58:78,8] = 228
A1[78:101,8] = 228
A1[101:147,8] = 251
A1[147:171,8] = 275

A1[0:20,9] = 176
A1[20:58,9] = 163
A1[58:78,9] = 150
A1[78:101,9] = 150
A1[101:147,9] = 216
A1[147:171,9] = 283

A1[0:20,10] = 223
A1[20:58,10] = 189
A1[58:78,10] = 154
A1[78:101,10] = 154
A1[101:147,10] = 220
A1[147:171,10] = 286


Q = np.zeros((M+1,N+1))

Q[a2:b2,0:b1] = 25.03 #Jan
Q[b2:c2,0:b1] = 14.06
Q[c2:d2,0:b1] = 3.09
Q[d2:e2,0:b1] = 3.09
Q[e2:f2,0:b1] = 98.25
Q[f2:g2,0:b1] = 193.41

Q[a2:b2,b1:c1] = 250.20 #Feb
Q[b2:c2,b1:c1] = 132.63
Q[c2:d2,b1:c1] = 15.05
Q[d2:e2,b1:c1] = 15.05
Q[e2:f2,b1:c1] = 58.59
Q[f2:g2,b1:c1] = 102.13

Q[a2:b2,c1:d1] = 98.67 #Mar
Q[b2:c2,c1:d1] = (98.67+27.9)/2
Q[c2:d2,c1:d1] = 27.9
Q[d2:e2,c1:d1] = 27.9
Q[e2:f2,c1:d1] = (27.9+22.24)/2
Q[f2:g2,c1:d1] = 22.24

Q[a2:b2,d1:e1] = 0.00 #April
Q[b2:c2,d1:e1] = 3.54
Q[c2:d2,d1:e1] = 7.08
Q[d2:e2,d1:e1] = 7.08
Q[e2:f2,d1:e1] = 47.47
Q[f2:g2,d1:e1] = 87.86

Q[a2:b2,e1:f1] = 67.86 # May
Q[b2:c2,e1:f1] = 35.30
Q[c2:d2,e1:f1] = 2.74
Q[d2:e2,e1:f1] = 2.74
Q[e2:f2,e1:f1] = 7.74
Q[f2:g2,e1:f1] = 12.75

Q[a2:b2,f1:g1] = 146.37 #June
Q[b2:c2,f1:g1] = 77.14
Q[c2:d2,f1:g1] = 7.90
Q[d2:e2,f1:g1] = 7.90
Q[e2:f2,f1:g1] = 81.09
Q[f2:g2,f1:g1] = 154.28

Q[a2:b2,g1:h1] = 185.23 #July
Q[b2:c2,g1:h1] = 96.23
Q[c2:d2,g1:h1] = 7.23
Q[d2:e2,g1:h1] = 7.23
Q[e2:f2,g1:h1] = 8.71
Q[f2:g2,g1:h1] = 10.20

Q[a2:b2,h1:i1] = 13.52 # Aug
Q[b2:c2,h1:i1] = 73.56
Q[c2:d2,h1:i1] = 133.61
Q[d2:e2,h1:i1] = 133.61
Q[e2:f2,h1:i1] = 137.68
Q[f2:g2,h1:i1] = 141.75

Q[a2:b2,i1:j1] = 136.18 # Sept
Q[b2:c2,i1:j1] = 81.77
Q[c2:d2,i1:j1] = 27.36
Q[d2:e2,i1:j1] = 27.36
Q[e2:f2,i1:j1] = 102.91
Q[f2:g2,i1:j1] = 178.46

Q[a2:b2,j1:k1] = 184.28 #October
Q[b2:c2,j1:k1] = 128.07
Q[c2:d2,j1:k1] = 71.87
Q[d2:e2,j1:k1] = 71.87
Q[e2:f2,j1:k1] = 129.34
Q[f2:g2,j1:k1] = 186.81

Q[a2:b2,k1:l1] = 196.20 #November
Q[b2:c2,k1:l1] = 113.53
Q[c2:d2,k1:l1] = 30.86
Q[d2:e2,k1:l1] = 30.86
Q[e2:f2,k1:l1] = 102.80
Q[f2:g2,k1:l1] = 174.73

# %%
from scipy.integrate import quad
#Solving for matrices L1, L2, L3
T =  28512000
L = 8500
den = 0.01       #density of CIMW and CMW
theta = 1       #porosity
l = 50          #element distance
K = 1000         #dispersion coefficient K=diffusion+dispersitivity*fv
dt = 360        #time step size
dx = 50
N = int(round(T/dt))          #no. of time steps
M = int(round(L/dx))          #no. of nodes

#Solving for L1, let E=E^m/E (to be solve)
def integrand(x):
    return -(-1/l)*(1-x/l)
ans1, err = quad(integrand, 0, l)

def integrand(x):
    return -(-1/l)*(x/l)
ans2, err = quad(integrand, 0, l)

def integrand(x):
    return -(1/l)*(1-x/l)
ans3, err = quad(integrand, 0, l)

def integrand(x):
    return -(1/l)*(x/l)
ans4, err = quad(integrand, 0, l)

L1 = diags([ans3,(ans1+ans4),ans2], [-1,0,1], shape=(M+1, M+1)).toarray()
L1[0, 0] = ans1
L1[M, M] = ans4
#L1 is to be multiplied by Q

#Solving for L2

def integrand(x):
    return (-1/l)*(-1/l)
ans12, err = quad(integrand, 0, l)

def integrand(x):
    return (-1/l)*(1/l)
ans13, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(-1/l)
ans14, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(1/l)
ans15, err = quad(integrand, 0, l)

L2 = diags([ans14,(ans12+ans15),ans13], [-1,0,1], shape=(M+1, M+1)).toarray()
L2[0,0] = ans12
L2[M,M] = ans15
#L2 is to be multiplied by K and A

#Solving for L3 is zero.

#Solving for M

def integrand(x):
    return (1-x/l)*(1-x/l)
ans20, err = quad(integrand, 0, l)

def integrand(x):
    return (1-x/l)*(x/l)
ans21, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(1-x/l)
ans22, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(x/l)
ans23, err = quad(integrand, 0, l)

Z = diags([ans22,(ans20+ans23),ans21], [-1,0,1], shape=(M+1, M+1)).toarray()
Z[0, 0] = ans20
Z[M, M] = ans23


(S,x,t, E) = solver(T,dt,L1, L2, Z)

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov"], [0.27, 0.27, 0.31, 0.50, 6.54, 4.33, 0.46, 0.49, 1.74, 0.46, 0.26], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov"],[S[0,7200], S[0,14400], S[0,21600], S[0,28800], S[0,36000], S[0,43200], S[0,50400], S[0,57600], S[0,64800], S[0,72000], S[0,79200]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("MTDS($g/m^3$)")
plt.title("TDS Bambang 2019, $K=1000$")
#plt.savefig('TDS March 2018, K=600, adjusted flow rate.png') 

plt.show()

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug","Sep", "Oct", "Nov"], [0.28, 0.28, 0.32, 0.70, 9.48, 9.16, 0.56, 0.35, 1.5, 0.46, 0.48], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov"],[S[72,7200], S[72,14400], S[72,21600], S[72,28800], S[72,36000], S[72,43200], S[72,50400], S[72,57600], S[72,64800], S[72,72000], S[72,79200]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("TDS($g/m^3$)")
plt.title("TDS Guadalupe 2019")
#plt.savefig('TDS Guadalupe 2019.png') 

plt.show()

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov"], [0.28, 0.32, 0.30, 1.95, 12.06, 14.76, 6.29, 0.36, 1.60, 0.46, 0.58], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov"], [S[170,7200], S[170,14400], S[170,21600], S[170,28800], S[170,36000], S[170,43200], S[170,50400], S[170,57600], S[170,64800], S[170,72000], S[170,79200]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("TDS($g/m^3$)")
plt.title("TDS Lambingan 2019")
#plt.savefig('TDS Lambingan 2019.png') 

plt.show()
