# %%
from scipy.sparse import diags #linalg
from scipy.linalg import solve
import numpy as np
from numpy.linalg import inv, det
from matplotlib import pyplot as plt

# %%
a1 = 0 
b1 = 7200
c1 = 2*b1
d1 = 3*b1
e1 = 4*b1
f1 = 5*b1
g1 = 6*b1
h1 = 7*b1
i1 = 8*b1
j1 = 9*b1
k1 = 10*b1
l1 = 11*b1
m1 = 12*b1
n1 = 13*b1
o1 = 14*b1
p1 = 15*b1
q1 = 16*b1
r1 = 17*b1

z = 0.01

# %%
#Depth per month of the sources
J1 = 3.5
J2 = 0
J3 = 0
J4 = 1.5
J5 = 1.06
J6 = 1.4

F1 = 4.46
F2 = 0
F3 = 0
F4 = 0.53
F5 = 0.93
F6 = 0.63

Mar1 = 2.8
Mar2 = 0 
Mar3 = 0
Mar4 = 0.26
Mar5 = 0.8
Mar6 = 1.56

Ap1 = 2.3
Ap2 = 0
Ap3 = 0
Ap4 = 0.33
Ap5 = 0.96
Ap6 = 0.96

Ma1 = 2.9
Ma2 = 0
Ma3 = 0
Ma4 = 0.63
Ma5 = 1.23
Ma6 = 0.96

Jun1 = 2.5
Jun2 = 0
Jun3 = 0
Jun4 = 0.56
Jun5 = 1.5
Jun6 = 1

Jul1 = 2.66
Jul2 = 0
Jul3 = 0
Jul4 = 0.86
Jul5 = 1.03
Jul6 = 0.9

Au1 = 3.9
Au2 = 0
Au3 = 0
Au4 = 0.66
Au5 = 0.96
Au6 = 2.1

S1 = 3.26
S2 = 0
S3 = 0
S4 = 1
S5 = 1.2
S6 = 1.6

O1 = 3.4
O2 = 0
O3 = 0
O4 = 1.3
O5 = 1.5
O6 = 1.7

N1 = 3.9
N2 = 0
N3 = 0
N4 = 0.83
N5 = 1.06
N6 = 1.4

D1 = 3.5
D2 = 0
D3 = 0
D4 = 0.23
D5 = 1.5
D6 = 0.63

# %%
#Wetted Perimeter
PJ1 = 2*J1 + 65
PJ2 = 2*J2 + 53
PJ3 = 2*J3 + 7
PJ4 = 2*J4 + 7
PJ5 = 2*J5 + 9
PJ6 = 2*J6 + 7

PF1 = 2*F1 + 65
PF2 = 2*F2 + 53
PF3 = 2*F3 + 7
PF4 = 2*F4 + 7
PF5 = 2*F5 + 9
PF6 = 2*F6 + 7

PMar1 = 2*Mar1 +  65
PMar2 = 2*Mar2 +  53
PMar3 = 2*Mar3 +  7
PMar4 = 2*Mar4 +  7
PMar5 = 2*Mar5 +  9
PMar6 = 2*Mar6 +  7

PAp1 = 2*Ap1 + 65
PAp2 = 2*Ap2 + 53
PAp3 = 2*Ap3 + 7
PAp4 = 2*Ap4 + 7
PAp5 = 2*Ap5 + 9
PAp6 = 2*Ap6 + 7

PMa1 = 2*Ma1 + 65
PMa2 = 2*Ma2 + 53
PMa3 = 2*Ma3 + 7
PMa4 = 2*Ma4 + 7
PMa5 = 2*Ma5 + 9
PMa6 = 2*Ma6 + 7

PJun1 = 2*Jun1 + 65
PJun2 = 2*Jun2 + 53
PJun3 = 2*Jun3 + 7
PJun4 = 2*Jun4 + 7
PJun5 = 2*Jun5 + 9
PJun6 = 2*Jun6 + 7

PJul1 = 2*Jul1 + 65
PJul2 = 2*Jul2 + 53
PJul3 = 2*Jul3 + 7
PJul4 = 2*Jul4 + 7
PJul5 = 2*Jul5 + 9
PJul6 = 2*Jul6 + 7

PAu1 = 2*Au1 + 65
PAu2 = 2*Au2 + 53
PAu3 = 2*Au3 + 7
PAu4 = 2*Au4 + 7
PAu5 = 2*Au5 + 9
PAu6 = 2*Au6 + 7

PS1 = 2*S1 + 65
PS2 = 2*S2 + 53
PS3 = 2*S3 + 7
PS4 = 2*S4 + 7
PS5 = 2*S5 + 9
PS6 = 2*S6 + 7

PO1 = 2*O1 + 65
PO2 = 2*O2 + 53
PO3 = 2*O3 + 7
PO4 = 2*O4 + 7
PO5 = 2*O5 + 9
PO6 = 2*O6 + 7

PN1 = 2*N1 + 65
PN2 = 2*N2 + 53
PN3 = 2*N3 + 7
PN4 = 2*N4 + 7
PN5 = 2*N5 + 9
PN6 = 2*N6 + 7

PD1 = 2*D1 + 65
PD2 = 2*D2 + 53
PD3 = 2*D3 + 7
PD4 = 2*D4 + 7
PD5 = 2*D5 + 9
PD6 = 2*D6 + 7

# %%
#depth and wetted perimeter of Guadalupe and Lambingan
DepthBamGuadJ = 3.32
DepthBamGuadF = 3.55
DepthBamGuadMar = 2.23
DepthBamGuadAp = 2.52
DepthBamGuadMa = 2.00
DepthBamGuadJun = 2.37
DepthBamGuadJul = 2.55
DepthBamGuadAu = 3.70
DepthBamGuadS = 3.13
DepthBamGuadO = 2.35
DepthBamGuadN = 3.52
DepthBamGuadD = 2.72


DepthGuadJ = 3.13
DepthGuadF = 2.63
DepthGuadMar = 1.66
DepthGuadAp = 2.73
DepthGuadMa = 1.10
DepthGuadJun = 2.23
DepthGuadJul = 2.43
DepthGuadAu = 3.50
DepthGuadS = 3.00
DepthGuadO = 1.30
DepthGuadN = 3.13
DepthGuadD = 1.93

DepthGuadLamJ = 2.98
DepthGuadLamF = 2.17
DepthGuadLamMar = 2.23
DepthGuadLamAp = 3.03
DepthGuadLamMa = 2.72
DepthGuadLamJun = 2.27
DepthGuadLamJul = 2.45
DepthGuadLamAu = 4.53
DepthGuadLamS = 3.92
DepthGuadLamO = 2.25
DepthGuadLamN = 4.27
DepthGuadLamD = 3.17

DepthLamJ = 2.83
DepthLamF = 1.70
DepthLamMar = 2.80
DepthLamAp = 3.33
DepthLamMa = 4.33
DepthLamJun = 2.30
DepthLamJul = 2.46
DepthLamAu = 5.56
DepthLamS = 4.83
DepthLamO = 3.20
DepthLamN = 5.40
DepthLamD = 4.40

PeriBamGuadJ = 2*DepthBamGuadJ + 70
PeriBamGuadF = 2*DepthBamGuadF + 70
PeriBamGuadMar = 2*DepthBamGuadMar + 70
PeriBamGuadAp = 2*DepthBamGuadAp + 70
PeriBamGuadMa = 2*DepthBamGuadMa + 70
PeriBamGuadJun = 2*DepthBamGuadJun + 70
PeriBamGuadJul = 2*DepthBamGuadJul + 70
PeriBamGuadAu = 2*DepthBamGuadAu + 70
PeriBamGuadS = 2*DepthBamGuadS + 70
PeriBamGuadO = 2*DepthBamGuadO + 70
PeriBamGuadN = 2*DepthBamGuadN + 70
PeriBamGuadD = 2*DepthBamGuadD + 70

PeriGuadJ = 2*DepthGuadJ + 76
PeriGuadF =  2*DepthGuadF + 76
PeriGuadMar =  2*DepthGuadMar + 76
PeriGuadAp =  2*DepthGuadAp + 76
PeriGuadMa =  2*DepthGuadMa + 76
PeriGuadJun =  2*DepthGuadJun + 76
PeriGuadJul =  2*DepthGuadJul + 76
PeriGuadAu =  2*DepthGuadAu + 76
PeriGuadS =  2*DepthGuadS + 76
PeriGuadO =  2*DepthGuadO + 76
PeriGuadN =  2*DepthGuadN + 76
PeriGuadD =  2*DepthGuadD + 76

PeriGuadLamJ = 2*DepthGuadLamJ + 80
PeriGuadLamF = 2*DepthGuadLamF + 80
PeriGuadLamMar = 2*DepthGuadLamMar + 80
PeriGuadLamAp = 2*DepthGuadLamAp + 80
PeriGuadLamMa = 2*DepthGuadLamMa + 80
PeriGuadLamJun = 2*DepthGuadLamJun + 80
PeriGuadLamJul = 2*DepthGuadLamJul + 80
PeriGuadLamAu = 2*DepthGuadLamAu + 80
PeriGuadLamS = 2*DepthGuadLamS + 80
PeriGuadLamO = 2*DepthGuadLamO + 80
PeriGuadLamN = 2*DepthGuadLamN + 80
PeriGuadLamD = 2*DepthGuadLamD + 80

PeriLamJ = 2*DepthLamJ + 85
PeriLamF = 2*DepthLamF + 85
PeriLamMar = 2*DepthLamMar + 85
PeriLamAp = 2*DepthLamAp + 85
PeriLamMa = 2*DepthLamMa + 85
PeriLamJun = 2*DepthLamJun + 85
PeriLamJul = 2*DepthLamJul + 85
PeriLamAu = 2*DepthLamAu + 85
PeriLamS = 2*DepthLamS + 85
PeriLamO = 2*DepthLamO + 85
PeriLamN = 2*DepthLamN + 85
PeriLamD = 2*DepthLamD + 85

hb = 1

# %%
def solver(T,dt, L2, Z):
    N = int(round(T/dt))
    t = np.linspace(0,T,N+1) #time discrete
    M = int(round(L/dx))
    x = np.linspace(0,L,M+1) #space discrete
    E = np.zeros((M+1,N+1))
    S = np.zeros((M+1,N+1))
    C = np.zeros((M+1,N+1))
    PPX = np.zeros((M+1))
    Em = np.zeros((M+1,N+1))
    Es = np.zeros((M+1,N+1))
    Elag = np.zeros((M+1,N+1))
    BM = np.zeros((M+1,11))
    Bi = np.zeros((M+1))
    RHS = np.zeros((M+1))
    B = np.zeros((M+1))
    A = np.zeros((M+1))
    QW = np.zeros((M+1,11))
    
    #initial conditions
    S[0,a1:b1] = 0.539
    S[0,b1:c1] = 0.42
    S[0,c1:d1] = 0.49
    S[0,d1:e1] = 0.46
    S[0,e1:f1] = 0.40
    S[0,f1:g1] = 0.45
    S[0,g1:h1] = 0.45
    S[0,h1:i1] = 0.37
    S[0,i1:j1] = 0.30
    S[0,j1:k1] = 1.36
    S[0,k1:l1] = 0.30
    S[0,l1:m1] = 0.30
    C[0,a1:b1] = z*S[0,a1:b1]
    C[0,b1:c1] = z*S[0,b1:c1]
    C[0,c1:d1] = z*S[0,c1:d1]
    C[0,d1:e1] = z*S[0,d1:e1]
    C[0,e1:f1] = z*S[0,e1:f1]
    C[0,f1:g1] = z*S[0,f1:g1]
    C[0,g1:h1] = z*S[0,g1:h1]
    C[0,h1:i1] = z*S[0,h1:i1]
    C[0,i1:j1] = z*S[0,i1:j1]
    C[0,j1:k1] = z*S[0,j1:k1]
    C[0,k1:l1] = z*S[0,k1:l1]
    C[0,l1:m1] = z*S[0,l1:m1]
    Em[0,a1:b1] = PJ1*den*hb*S[0,a1:b1]
    Em[0,b1:c1] = PF1*den*hb*S[0,b1:c1]
    Em[0,c1:d1] = PMar1*den*hb*S[0,c1:d1]
    Em[0,d1:e1] = PAp1*den*hb*S[0,d1:e1]
    Em[0,e1:f1] = PMa1*den*hb*S[0,e1:f1]
    Em[0,f1:g1] = PJun1*den*hb*S[0,f1:g1]
    Em[0,g1:h1] = PJul1*den*hb*S[0,g1:h1]
    Em[0,h1:i1] = PAu1*den*hb*S[0,h1:i1]
    Em[0,i1:j1] = PS1*den*S1*S[0,i1:j1]
    Em[0,j1:k1] = PO1*den*hb*S[0,j1:k1]
    Em[0,k1:l1] = PN1*den*hb*S[0,k1:l1]
    Em[0,l1:m1] = PD1*den*hb*S[0,l1:m1]
    
    
    #special time step at n=0
    A = A1[:,0]
    a4 = 9-Jk1
    b4 = b2-Jk1
    Elag[0:9, 1] = Em[0,0]
    Elag[9:b2,1] = Em[a4:b4,0]+(Jv1*dt-Jk1*dx)*((Em[a4-1:b4-1,0]-Em[a4:b4,0])/dx)
    Elag[b2:c2,1] = Em[b2-Jk2:c2-Jk2,0]+(Jv2*dt-Jk2*dx)*((Em[b2-Jk2-1:c2-Jk2-1,0]-Em[b2-Jk2:c2-Jk2,0])/dx)
    Elag[c2:d2,1] = Em[c2-Jk3:d2-Jk3,0]+(Jv3*dt-Jk3*dx)*((Em[c2-Jk3-1:d2-Jk3-1,0]-Em[c2-Jk3:d2-Jk3,0])/dx)
    Elag[d2:e2,1] = Em[d2-Jk4:e2-Jk4,0]+(Jv4*dt-Jk4*dx)*((Em[d2-Jk4-1:e2-Jk4-1,0]-Em[d2-Jk4:e2-Jk4,0])/dx)
    Elag[e2:f2,1] = Em[e2-Jk5:f2-Jk5,0]+(Jv5*dt-Jk5*dx)*((Em[e2-Jk5-1:f2-Jk5-1,0]-Em[e2-Jk5:f2-Jk5,0])/dx)
    Elag[f2:g2,1] = Em[f2-Jk6:g2-Jk6,0]+(Jv6*dt-Jk6*dx)*((Em[f2-Jk6-1:g2-Jk6-1,0]-Em[f2-Jk6:g2-Jk6,0])/dx)
    L2 = np.multiply(L2, A)
    Z = np.multiply(Z,A)
    Z1 = np.sum(Z, axis = 1)
    L2 = np.divide(L2, Z1)
    M2 = U/dt
    M1 = U / dt +  (L2*K)
    BM[0,0] = (PJ1*den*hb*0.539)/Z1[0] 
    BM[24,0] = (PJ2*den*J2*0)/Z1[24] 
    BM[66,0] = (PJ3*den*J3*0)/Z1[66] 
    BM[72,0] = (PJ4*den*J4*0.297)/Z1[72] 
    BM[88,0] = (PJ5*den*J5*0.352)/Z1[88] 
    BM[148,0] = (PJ6*den*J6*0.386)/Z1[148] 
    B = BM[:,0]
    RHS[:] = M2.dot(Elag[:,1]) + B
    Es[:,1] = np.linalg.solve(M1, RHS)
    E[:,1] = Es[:,1] + C[:,0]
    S[0,1] = S[0,b1-1]
    S[1:b2,1] = E[1:b2,1] / (den*PJ1*hb+z*den*PJ1*hb*theta)
    S[b2:c2,1] = E[b2:c2,1] / (den*PeriBamGuadJ*hb+z*den*PeriBamGuadJ*hb*theta)
    S[c2:d2,1] = E[c2:d2,1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
    S[d2:e2,1] = E[d2:e2,1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
    S[e2:f2,1] = E[e2:f2,1] / (den*PeriGuadLamJ*hb+z*den*PeriGuadLamJ*hb*theta)
    S[f2:g2,1] = E[f2:g2,1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
    S[g2:h2,1] = E[g2:h2,1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
    Em[0:b2,1] = den*PJ1*hb*S[0:b2,1]
    Em[b2:c2,1] = den*PeriBamGuadJ*hb*S[b2:c2,1]
    Em[c2:d2,1] = den*PeriGuadJ*hb*S[c2:d2,1]
    Em[d2:e2,1] = den*PeriGuadJ*hb*S[d2:e2,1]
    Em[e2:f2,1] = den*PeriGuadLamJ*hb*S[e2:f2,1]
    Em[f2:g2,1] = den*PeriLamJ*hb*S[f2:g2,1]
    Em[g2:h2,1] = den*PeriLamJ*hb*S[g2:h2,1]
    C[:,1] = z*S[:,1]
    
    
    
    for n in range(1,N):
        #update all matrices
        if n<=b1: #January
            A = A1[:,0]
            a4 = 9-Jk1
            b4 = b2-Jk1
            Elag[0:9, n+1] = Em[0,n]
            Elag[9:b2,n+1] = Em[a4:b4,n]+(Jv1*dt-Jk1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Jk2:c2-Jk2,n]+(Jv2*dt-Jk2*dx)*((Em[b2-Jk2-1:c2-Jk2-1,n]-Em[b2-Jk2:c2-Jk2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Jk3:d2-Jk3,n]+(Jv3*dt-Jk3*dx)*((Em[c2-Jk3-1:d2-Jk3-1,n]-Em[c2-Jk3:d2-Jk3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Jk4:e2-Jk4,n]+(Jv4*dt-Jk4*dx)*((Em[d2-Jk4-1:e2-Jk4-1,n]-Em[d2-Jk4:e2-Jk4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Jk5:f2-Jk5,n]+(Jv5*dt-Jk5*dx)*((Em[e2-Jk5-1:f2-Jk5-1,n]-Em[e2-Jk5:f2-Jk5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Jk6:g2-Jk6,n]+(Jv6*dt-Jk6*dx)*((Em[f2-Jk6-1:g2-Jk6-1,n]-Em[f2-Jk6:g2-Jk6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,0] = (PJ1*den*hb*0.539)/Z1[0] 
            BM[24,0] = (PJ2*den*J2*0)/Z1[24] 
            BM[66,0] = (PJ3*den*J3*0)/Z1[66] 
            BM[72,0] = (PJ4*den*J4*0.297)/Z1[72] 
            BM[88,0] = (PJ5*den*J5*0.352)/Z1[88] 
            BM[148,0] = (PJ6*den*J6*0.386)/Z1[148] 
            B = BM[:,0]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PJ1*den*hb*0.539
            #RHS[M] = -193.41*Elag[M,n] #possible pa ni sya dli mao, double check lang ni nako later.
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            #Es[Es<0] = 0
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,b1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PJ1*hb+z*den*PJ1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadJ*hb+z*den*PeriBamGuadJ*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadJ*hb+z*den*PeriGuadJ*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamJ*hb+z*den*PeriGuadLamJ*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamJ*hb+z*den*PeriLamJ*hb*theta)
            Em[0:b2,n+1] = den*PJ1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadJ*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadJ*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadJ*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamJ*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamJ*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamJ*hb*S[g2:h2,n+1]
            C[:,n+1] = z*S[:,n+1]
            
        if b1<n<=c1: #February
            A = A1[:,1]
            a4 = 2-Fk1
            b4 = b2-Fk1
            Elag[0:2, n+1] = Em[0,n]
            Elag[2:b2,n+1] = Em[a4:b4,n]+(Fv1*dt-Fk1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Fk2:c2-Fk2,n]+(Fv2*dt-Fk2*dx)*((Em[b2-Fk2-1:c2-Fk2-1,n]-Em[b2-Fk2:c2-Fk2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Fk3:d2-Fk3,n]+(Fv3*dt-Fk3*dx)*((Em[c2-Fk3-1:d2-Fk3-1,n]-Em[c2-Fk3:d2-Fk3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Fk4:e2-Fk4,n]+(Fv4*dt-Fk4*dx)*((Em[d2-Fk4-1:e2-Fk4-1,n]-Em[d2-Fk4:e2-Fk4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Fk5:f2-Fk5,n]+(Fv5*dt-Fk5*dx)*((Em[e2-Fk5-1:f2-Fk5-1,n]-Em[e2-Fk5:f2-Fk5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Fk6:g2-Fk6,n]+(Fv6*dt-Fk6*dx)*((Em[f2-Fk6-1:g2-Fk6-1,n]-Em[f2-Fk6:g2-Fk6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,1] = (PF1*den*hb*0.42) /Z1[0] 
            BM[24,1] = (PF2*den*F2*0+z*PF2*F2*den*theta*0)/Z1[24]
            BM[66,1] = (PF3*den*F3*0+z*PF3*F3*den*theta*0)/Z1[66]
            BM[72,1] = (PF4*den*F4*0.46+z*PF4*F4*den*theta*0.46)/Z1[72]
            BM[88,1] = (PF5*den*F5*0.41+z*PF5*F5*den*theta*0.41)/Z1[88]
            BM[148,1] = (PF6*den*F6*0.39+z*PF6*F6*den*theta*0.39)/Z1[148]
            B = BM[:,1]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PF1*den*hb*0.42
            #RHS[M] = -102.13*Elag[M,n] #possible pa ni sya dli mao, doible check lang ni nako later.
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,c1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PF1*hb+z*den*PF1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadF*hb+z*den*PeriBamGuadF*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadF*hb+z*den*PeriGuadF*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadF*hb+z*den*PeriGuadF*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamF*hb+z*den*PeriGuadLamF*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamF*hb+z*den*PeriLamF*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamF*hb+z*den*PeriLamF*hb*theta)
            Em[0:b2,n+1] = den*PF1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadF*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadF*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadF*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamF*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamF*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamF*hb*S[g2:h2,n+1]
            C[:,n+1] = z*S[:,n+1]
            
        if c1<n<=d1: #March
            A = A1[:,2]
            a4 = 9-Mark1
            b4 = b2-Mark1
            Elag[0:9, n+1] = Em[0,n]
            Elag[9:b2,n+1] = Em[a4:b4,n]+(Marv1*dt-Mark1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Mark2:c2-Mark2,n]+(Marv2*dt-Mark2*dx)*((Em[b2-Mark2-1:c2-Mark2-1,n]-Em[b2-Mark2:c2-Mark2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Mark3:d2-Mark3,n]+(Marv3*dt-Mark3*dx)*((Em[c2-Mark3-1:d2-Mark3-1,n]-Em[c2-Mark3:d2-Mark3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Mark4:e2-Mark4,n]+(Marv4*dt-Mark4*dx)*((Em[d2-Mark4-1:e2-Mark4-1,n]-Em[d2-Mark4:e2-Mark4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Mark5:f2-Mark5,n]+(Marv5*dt-Mark5*dx)*((Em[e2-Mark5-1:f2-Mark5-1,n]-Em[e2-Mark5:f2-Mark5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Mark6:g2-Mark6,n]+(Marv6*dt-Mark6*dx)*((Em[f2-Mark6-1:g2-Mark6-1,n]-Em[f2-Mark6:g2-Mark6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,2] = (PMar1*den*hb*0.49) /Z1[0]
            BM[24,2] = (PMar2*den*Mar2*0+z*PMar2*den*Mar2*theta*0)/Z1[24]
            BM[66,2] = (PMar3*den*Mar3*0+z*PMar3*den*Mar3*theta*0)/Z1[66]
            BM[72,2] = (PMar4*den*Mar4*0.46+z*PMar4*den*Mar4*theta*0.46)/Z1[72]
            BM[88,2] = (PMar5*den*Mar5*0.38+z*PMar5*den*Mar5*theta*0.38)/Z1[88]
            BM[148,2] = (PMar6*den*Mar6*0.40+z*PMar6*den*Mar6*theta*0.40)/Z1[148]
            B = BM[:,2]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PMar1*den*hb*0.49
            #RHS[M] = -22.24*Elag[M,n] #possible pa ni sya dli mao, doible check lang ni nako later.
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,d1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PMar1*hb+z*den*PMar1*1*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadMar*hb+z*den*PeriBamGuadMar*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadMar*hb+z*den*PeriGuadMar*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadMar*hb+z*den*PeriGuadMar*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamMar*hb+z*den*PeriGuadLamMar*1*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamMar*hb+z*den*PeriLamMar*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamMar*hb+z*den*PeriLamMar*hb*theta)
            Em[0:b2,n+1] = den*PMar1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadMar*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadMar*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadMar*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamMar*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamMar*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamMar*hb*S[g2:h2,n+1]
            C[:,n+1] = z* S[:,n+1]
            
        if d1<n<=e1: #April
            A = A1[:,3]
            a4 = 1-Apk1
            b4 = b2-Apk1
            Elag[0:1, n+1] = Em[0,n]
            Elag[1:b2,n+1] = Em[a4:b4,n]+(Apv1*dt-Apk1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Apk2:c2-Apk2,n]+(Apv2*dt-Apk2*dx)*((Em[b2-Apk2-1:c2-Apk2-1,n]-Em[b2-Apk2:c2-Apk2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Apk3:d2-Apk3,n]+(Apv3*dt-Apk3*dx)*((Em[c2-Apk3-1:d2-Apk3-1,n]-Em[c2-Apk3:d2-Apk3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Apk4:e2-Apk4,n]+(Apv4*dt-Apk4*dx)*((Em[d2-Apk4-1:e2-Apk4-1,n]-Em[d2-Apk4:e2-Apk4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Apk5:f2-Apk5,n]+(Apv5*dt-Apk5*dx)*((Em[e2-Apk5-1:f2-Apk5-1,n]-Em[e2-Apk5:f2-Apk5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Apk6:g2-Apk6,n]+(Apv6*dt-Apk6*dx)*((Em[f2-Apk6-1:g2-Apk6-1,n]-Em[f2-Apk6:g2-Apk6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,3] = (PAp2*den*Ap2*0.46)/Z1[0]
            BM[24,3] = (PAp2*den*Ap2*0+z*PAp2*den*Ap2*theta*0)/Z1[24]
            BM[66,3] = (PAp3*den*Ap3*0+z*PAp3*den*Ap3*theta*0)/Z1[66]
            BM[72,3] = (PAp4*den*Ap4*0.44+z*PAp4*den*Ap4*theta*0.44)/Z1[72]
            BM[88,3] = (PAp5*den*Ap5*0.43+z*PAp5*den*Ap5*theta*0.43)/Z1[88]
            BM[148,3] = (PAp6*den*Ap6*0.37+z*PAp6*den*Ap6*theta*0.37)/Z1[148]
            B = BM[:,3]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PAp1*den*hb*0.46
            #RHS[M] = -87.86*Elag[M,n] #possible pa ni sya dli mao, doible check lang ni nako later.
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,e1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PAp1*hb+z*den*PAp1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadAp*hb+z*den*PeriBamGuadAp*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadAp*hb+z*den*PeriGuadAp*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadAp*hb+z*den*PeriGuadAp*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamAp*hb+z*den*PeriGuadLamAp*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamAp*hb+z*den*PeriLamAp*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamAp*hb+z*den*PeriLamAp*hb*theta)
            Em[0:b2,n+1] = den*PAp1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadAp*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadAp*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadAp*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamAp*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamAp*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamAp*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if e1<n<=f1: #May
            A = A1[:,4]
            a4 = 3-Mak1
            b4 = b2-Mak1
            Elag[0:3, n+1] = Em[0,n]
            Elag[3:b2,n+1] = Em[a4:b4,n]+(Mav1*dt-Mak1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Mak2:c2-Mak2,n]+(Mav2*dt-Mak2*dx)*((Em[b2-Mak2-1:c2-Mak2-1,n]-Em[b2-Mak2:c2-Mak2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Mak3:d2-Mak3,n]+(Mav3*dt-Mak3*dx)*((Em[c2-Mak3-1:d2-Mak3-1,n]-Em[c2-Mak3:d2-Mak3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Mak4:e2-Mak4,n]+(Mav4*dt-Mak4*dx)*((Em[d2-Mak4-1:e2-Mak4-1,n]-Em[d2-Mak4:e2-Mak4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Mak5:f2-Mak5,n]+(Mav5*dt-Mak5*dx)*((Em[e2-Mak5-1:f2-Mak5-1,n]-Em[e2-Mak5:f2-Mak5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Mak6:g2-Mak6,n]+(Mav6*dt-Mak6*dx)*((Em[f2-Mak6-1:g2-Mak6-1,n]-Em[f2-Mak6:g2-Mak6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,4] = Em[0,f1-1]/Z1[0]
            BM[24,4] = (PMa2*den*Ma2*0+z*PMa2*den*Ma2*theta*0)/Z1[24]
            BM[66,4] = (PMa3*den*Ma3*0+z*PMa3*den*Ma3*theta*0)/Z1[66]
            BM[72,4] = (PMa4*den*Ma4*0.51+z*PMa4*den*Ma4*theta*0.5)/Z1[72]
            BM[88,4] = (PMa5*den*Ma5*0.42+z*PMa5*den*Ma5*theta*0.42)/Z1[88]
            BM[148,4] = (PMa6*den*Ma6*0.42+z*PMa6*den*Ma6*theta*0.42)/Z1[148]
            B = BM[:,4]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PMa1*den*hb*0.40
            #RHS[M] = -12.75*Elag[M,n] #possible pa ni sya dli mao, doible check lang ni nako later.
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,f1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PMa1*hb+z*den*PMa1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadMa*hb+z*den*PeriBamGuadMa*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadMa*hb+z*den*PeriGuadMa*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadMa*hb+z*den*PeriGuadMa*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamMa*hb+z*den*PeriGuadLamMa*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamMa*hb+z*den*PeriLamMa*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamMa*hb+z*den*PeriLamMa*hb*theta)
            Em[0:b2,n+1] = den*PMa1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadMa*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadMa*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadMa*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamMa*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamMa*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamMa*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if f1<n<=g1: #June
            A = A1[:,5] 
            a4 = 7-Junk1
            b4 = b2-Junk1
            Elag[0:7, n+1] = Em[0,n]
            Elag[7:b2,n+1] = Em[a4:b4,n]+(Junv1*dt-Junk1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Junk2:c2-Junk2,n]+(Junv2*dt-Junk2*dx)*((Em[b2-Junk2-1:c2-Junk2-1,n]-Em[b2-Junk2:c2-Junk2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Junk3:d2-Junk3,n]+(Junv3*dt-Junk3*dx)*((Em[c2-Junk3-1:d2-Junk3-1,n]-Em[c2-Junk3:d2-Junk3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Junk4:e2-Junk4,n]+(Junv4*dt-Junk4*dx)*((Em[d2-Junk4-1:e2-Junk4-1,n]-Em[d2-Junk4:e2-Junk4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Junk5:f2-Junk5,n]+(Junv5*dt-Junk5*dx)*((Em[e2-Junk5-1:f2-Junk5-1,n]-Em[e2-Junk5:f2-Junk5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Junk6:g2-Junk6,n]+(Junv6*dt-Junk6*dx)*((Em[f2-Junk6-1:g2-Junk6-1,n]-Em[f2-Junk6:g2-Junk6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,5] = Em[0,g1-1]/Z1[0]
            BM[24,5] = (PJun2*den*Jun2*0+z*PJun2*den*Jun2*theta*0)/Z1[24]
            BM[66,5] = (PJun3*den*Jun3*0+z*PJun3*den*Jun3*theta*0)/Z1[66]
            BM[72,5] = (PJun4*den*Jun4*0.45+z*PJun4*den*Jun4*theta*0.45)/Z1[72]
            BM[88,5] = (PJun5*den*Jun5*0.43+z*PJun5*den*Jun5*theta*0.43)/Z1[88]
            BM[148,5] = (PJun6*den*Jun6*0.34+z*PJun6*den*Jun6*theta*0.34)/Z1[148]
            B = BM[:,5]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PJun1*den*hb*0.45
            #RHS[M] = -154.28*Elag[M,n]
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,g1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PJun1*hb+z*den*PJun1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadJun*hb+z*den*PeriBamGuadJun*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadJun*hb+z*den*PeriGuadJun*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadJun*hb+z*den*PeriGuadJun*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamJun*hb+z*den*PeriGuadLamJun*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamJun*hb+z*den*PeriLamJun*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamJun*hb+z*den*PeriLamJun*hb*theta)
            Em[0:b2,n+1] = den*PJun1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadJun*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadJun*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadJun*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamJun*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamJun*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamJun*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if g1<n<=h1: #July
            A = A1[:,6]
            a4 = 2-Julk1
            b4 = b2-Julk1
            Elag[0:2, n+1] = Em[0,n]
            Elag[2:b2,n+1] = Em[a4:b4,n]+(Julv1*dt-Julk1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Julk2:c2-Julk2,n]+(Julv2*dt-Julk2*dx)*((Em[b2-Julk2-1:c2-Julk2-1,n]-Em[b2-Julk2:c2-Julk2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Julk3:d2-Julk3,n]+(Julv3*dt-Julk3*dx)*((Em[c2-Julk3-1:d2-Julk3-1,n]-Em[c2-Julk3:d2-Julk3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Julk4:e2-Julk4,n]+(Julv4*dt-Julk4*dx)*((Em[d2-Julk4-1:e2-Julk4-1,n]-Em[d2-Julk4:e2-Julk4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Julk5:f2-Julk5,n]+(Julv5*dt-Julk5*dx)*((Em[e2-Julk5-1:f2-Julk5-1,n]-Em[e2-Julk5:f2-Julk5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Julk6:g2-Julk6,n]+(Julv6*dt-Julk6*dx)*((Em[f2-Julk6-1:g2-Julk6-1,n]-Em[f2-Julk6:g2-Julk6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,6] = Em[0,h1-1] /Z1[0]
            BM[24,6] = (PJul2*den*Jul2*0+z*PJul2*den*Jul2*theta*0)/Z1[24]
            BM[66,6] = (PJul3*den*Jul3*0+z*PJul3*den*Jul3*theta*0)/Z1[66]
            BM[72,6] = (PJul4*den*Jul4*0.51+z*PJul4*den*Jul4*theta*0.51)/Z1[72]
            BM[88,6] = (PJul5*den*Jul5*0.42+z*PJul5*den*Jul5*theta*0.42)/Z1[88]
            BM[148,6] = (PJul6*den*Jul6*0.36+z*PJul6*den*Jul6*theta*0.36)/Z1[148]
            B = BM[:,6]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PJul1*den*hb*0.45
            #RHS[M] = -10.20*Em[M,n]
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,h1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PJul1*hb+z*den*PJul1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadJul*hb+z*den*PeriBamGuadJul*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadJul*hb+z*den*PeriGuadJul*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadJul*hb+z*den*PeriGuadJul*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamJul*hb+z*den*PeriGuadLamJul*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamJul*hb+z*den*PeriLamJul*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamJul*hb+z*den*PeriLamJul*hb*theta)
            Em[0:b2,n+1] = den*PJul1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadJul*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadJul*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadJul*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamJul*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamJul*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamJul*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if h1<n<=i1: #August
            A = A1[:,7]
            a4 = 2-Auk1
            b4 = b2-Auk1
            Elag[0:2, n+1] = Em[0,n]
            Elag[2:b2,n+1] = Em[a4:b4,n]+(Auv1*dt-Auk1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Auk2:c2-Auk2,n]+(Auv2*dt-Auk2*dx)*((Em[b2-Auk2-1:c2-Auk2-1,n]-Em[b2-Auk2:c2-Auk2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Auk3:d2-Auk3,n]+(Auv3*dt-Auk3*dx)*((Em[c2-Auk3-1:d2-Auk3-1,n]-Em[c2-Auk3:d2-Auk3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Auk4:e2-Auk4,n]+(Auv4*dt-Auk4*dx)*((Em[d2-Auk4-1:e2-Auk4-1,n]-Em[d2-Auk4:e2-Auk4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Auk5:f2-Auk5,n]+(Auv5*dt-Auk5*dx)*((Em[e2-Auk5-1:f2-Auk5-1,n]-Em[e2-Auk5:f2-Auk5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Auk6:g2-Auk6,n]+(Auv6*dt-Auk6*dx)*((Em[f2-Auk6-1:g2-Auk6-1,n]-Em[f2-Auk6:g2-Auk6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,7] = Em[0,i1-1] /Z1[0]
            BM[24,7] = (PAu2*den*Au2*0+z*PAu2*den*Au2*theta*0)/Z1[24]
            BM[66,7] = (PAu3*den*Au3*0+z*PAu3*den*Au3*theta*0)/Z1[66]
            BM[72,7] = (PAu4*den*Au4*0.34+z*PAu4*den*Au4*theta*0.34)/Z1[72]
            BM[88,7] = (PAu5*den*Au5*0.32+z*PAu5*den*Au5*theta*0.32)/Z1[88]
            BM[148,7] = (PAu6*den*Au6*0.18+z*PAu6*den*Au6*theta*0.18)/Z1[148]
            B = BM[:,7]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PAu1*den*hb*0.37
            #RHS[M] = -141.75*Elag[M,n]
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,i1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PAu1*hb+z*den*PAu1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadAu*hb+z*den*PeriBamGuadAu*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadAu*hb+z*den*PeriGuadAu*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadAu*hb+z*den*PeriGuadAu*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamAu*hb+z*den*PeriGuadLamAu*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamAu*hb+z*den*PeriLamAu*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamAu*hb+z*den*PeriLamAu*hb*theta)
            Em[0:b2,n+1] = den*PAu1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadAu*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadAu*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadAu*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamAu*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamAu*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamAu*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if i1<n<=j1: #September
            A = A1[:,8]
            a4 = 3-Sk1
            b4 = b2-Sk1
            Elag[0:3, n+1] = Em[0,n]
            Elag[3:b2,n+1] = Em[a4:b4,n]+(Sv1*dt-Sk1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Sk2:c2-Sk2,n]+(Sv2*dt-Sk2*dx)*((Em[b2-Sk2-1:c2-Sk2-1,n]-Em[b2-Sk2:c2-Sk2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Sk3:d2-Sk3,n]+(Sv3*dt-Sk3*dx)*((Em[c2-Sk3-1:d2-Sk3-1,n]-Em[c2-Sk3:d2-Sk3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Sk4:e2-Sk4,n]+(Sv4*dt-Sk4*dx)*((Em[d2-Sk4-1:e2-Sk4-1,n]-Em[d2-Sk4:e2-Sk4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Sk5:f2-Sk5,n]+(Sv5*dt-Sk5*dx)*((Em[e2-Sk5-1:f2-Sk5-1,n]-Em[e2-Sk5:f2-Sk5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Sk6:g2-Sk6,n]+(Sv6*dt-Sk6*dx)*((Em[f2-Sk6-1:g2-Sk6-1,n]-Em[f2-Sk6:g2-Sk6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,8] = Em[0,j1-1]  /Z1[0]
            BM[24,8] = (PS2*den*S2*0+z*PS2*den*S2*theta*0)/Z1[24]
            BM[66,8] = (PS3*den*S3*0+z*PS3*den*S3*theta*0)/Z1[66]
            BM[72,8] = (PS4*den*S4*0.48+z*PS4*den*S4*theta*0.48)/Z1[72]
            BM[88,8] = (PS5*den*S5*0.35+z*PS5*den*S5*theta*0.35)/Z1[88]
            BM[148,8] = (PS6*den*S6*0.33+z*PS6*den*S6*theta*0.33)/Z1[148]
            B = BM[:,8]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PS1*den*hb*0.30
            #RHS[M] = -178.46*Elag[M,n]
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,j1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PS1*hb+z*den*PS1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadS*hb+z*den*PeriBamGuadS*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadS*hb+z*den*PeriGuadS*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadS*hb+z*den*PeriGuadS*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamS*hb+z*den*PeriGuadLamS*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamS*hb+z*den*PeriLamS*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamS*hb+z*den*PeriLamS*hb*theta)
            Em[0:b2,n+1] = den*PS1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadS*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadS*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadS*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamS*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamS*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamS*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if j1<n<=k1: #October
            A = A1[:,9]
            a4 = 3-Ok1
            b4 = b2-Ok1
            Elag[0:3, n+1] = Em[0,n]
            Elag[3:b2,n+1] = Em[a4:b4,n]+(Ov1*dt-Ok1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Ok2:c2-Ok2,n]+(Ov2*dt-Ok2*dx)*((Em[b2-Ok2-1:c2-Ok2-1,n]-Em[b2-Ok2:c2-Ok2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Ok3:d2-Ok3,n]+(Ov3*dt-Ok3*dx)*((Em[c2-Ok3-1:d2-Ok3-1,n]-Em[c2-Ok3:d2-Ok3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Ok4:e2-Ok4,n]+(Ov4*dt-Ok4*dx)*((Em[d2-Ok4-1:e2-Ok4-1,n]-Em[d2-Ok4:e2-Ok4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Ok5:f2-Ok5,n]+(Ov5*dt-Ok5*dx)*((Em[e2-Ok5-1:f2-Ok5-1,n]-Em[e2-Ok5:f2-Ok5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Ok6:g2-Ok6,n]+(Ov6*dt-Ok6*dx)*((Em[f2-Ok6-1:g2-Ok6-1,n]-Em[f2-Ok6:g2-Ok6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,9] = Em[0,k1-1] /Z1[0]
            BM[24,9] = (PO2*den*O2*0+z*PO2*den*O2*theta*0)/Z1[24]
            BM[66,9] = (PO3*den*O3*0+z*PO3*den*O3*theta*0)/Z1[66]
            BM[72,9] = (PO4*den*O4*0.51+z*PO4*den*O4*theta*0.51)/Z1[72]
            BM[88,9] = (PO5*den*O5*0.62+z*PO5*den*O5*theta*0.62)/Z1[88]
            BM[148,9] = (PO6*den*O6*0.86+z*PO6*den*O6*theta*0.86)/Z1[148]
            B = BM[:,9]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PO1*den*hb*1.36
            #RHS[M] = -186.81*Elag[M,n]
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,k1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PO1*hb+z*den*PO1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadO*hb+z*den*PeriBamGuadO*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadO*hb+z*den*PeriGuadO*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadO*hb+z*den*PeriGuadO*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamO*hb+z*den*PeriGuadLamO*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamO*hb+z*den*PeriLamO*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamO*hb+z*den*PeriLamO*hb*theta)
            Em[0:b2,n+1] = den*PO1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadO*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadO*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadO*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamO*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamO*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamO*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if k1<n<=l1: #November
            A = A1[:,10]
            a4 = 1-Nk1
            b4 = b2-Nk1
            Elag[0:1, n+1] = Em[0,n]
            Elag[1:b2,n+1] = Em[a4:b4,n]+(Nv1*dt-Nk1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Nk2:c2-Nk2,n]+(Nv2*dt-Nk2*dx)*((Em[b2-Nk2-1:c2-Nk2-1,n]-Em[b2-Nk2:c2-Nk2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Nk3:d2-Nk3,n]+(Nv3*dt-Nk3*dx)*((Em[c2-Nk3-1:d2-Nk3-1,n]-Em[c2-Nk3:d2-Nk3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Nk4:e2-Nk4,n]+(Nv4*dt-Nk4*dx)*((Em[d2-Nk4-1:e2-Nk4-1,n]-Em[d2-Nk4:e2-Nk4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Nk5:f2-Nk5,n]+(Nv5*dt-Nk5*dx)*((Em[e2-Nk5-1:f2-Nk5-1,n]-Em[e2-Nk5:f2-Nk5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Nk6:g2-Nk6,n]+(Nv6*dt-Nk6*dx)*((Em[f2-Nk6-1:g2-Nk6-1,n]-Em[f2-Nk6:g2-Nk6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,10] = Em[0,l1-1] /Z1[0]
            BM[24,10] = (PN2*den*N2*0+z*PN2*den*N2*theta*0)/Z1[24]
            BM[66,10] = (PN3*den*N3*0+z*PN3*den*N3*theta*0)/Z1[66]
            BM[72,10] = (PN4*den*N4*0.45+z*PN4*den*N4*theta*0.45)/Z1[72]
            BM[88,10] = (PN5*den*N5*0.36+z*PN5*den*N5*theta*0.36)/Z1[88]
            BM[148,10] = (PN6*den*N6*0.38+z*PN6*den*N6*theta*0.38)/Z1[148]
            B = BM[:,10]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PN1*den*hb*0.30
            #RHS[M] = -174.73*Elag[M,n]
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,l1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PN1*hb+z*den*PN1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadN*hb+z*den*PeriBamGuadN*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadN*hb+z*den*PeriGuadN*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadN*hb+z*den*PeriGuadN*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamN*hb+z*den*PeriGuadLamN*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamN*hb+z*den*PeriLamN*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamN*hb+z*den*PeriLamN*hb*theta)
            Em[0:b2,n+1] = den*PN1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadN*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadN*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadN*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamN*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamN*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamN*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
        if l1<n<=m1: #December
            A = A1[:,11]
            a4 = 2-Dk1
            b4 = b2-Dk1
            Elag[0:2, n+1] = Em[0,n]
            Elag[2:b2,n+1] = Em[a4:b4,n]+(Dv1*dt-Dk1*dx)*((Em[a4-1:b4-1,n]-Em[a4:b4,n])/dx)
            Elag[b2:c2,n+1] = Em[b2-Dk2:c2-Dk2,n]+(Dv2*dt-Dk2*dx)*((Em[b2-Dk2-1:c2-Dk2-1,n]-Em[b2-Dk2:c2-Dk2,n])/dx)
            Elag[c2:d2,n+1] = Em[c2-Dk3:d2-Dk3,n]+(Dv3*dt-Dk3*dx)*((Em[c2-Dk3-1:d2-Dk3-1,n]-Em[c2-Dk3:d2-Dk3,n])/dx)
            Elag[d2:e2,n+1] = Em[d2-Dk4:e2-Dk4,n]+(Dv4*dt-Dk4*dx)*((Em[d2-Dk4-1:e2-Dk4-1,n]-Em[d2-Dk4:e2-Dk4,n])/dx)
            Elag[e2:f2,n+1] = Em[e2-Dk5:f2-Dk5,n]+(Dv5*dt-Dk5*dx)*((Em[e2-Dk5-1:f2-Dk5-1,n]-Em[e2-Dk5:f2-Dk5,n])/dx)
            Elag[f2:g2,n+1] = Em[f2-Dk6:g2-Dk6,n]+(Dv6*dt-Dk6*dx)*((Em[f2-Dk6-1:g2-Dk6-1,n]-Em[f2-Dk6:g2-Dk6,n])/dx)
            L2 = np.multiply(L2, A)
            Z = np.multiply(Z,A)
            Z1 = np.sum(Z, axis = 1)
            L2 = np.divide(L2, Z1)
            M2 = U/dt
            M1 = U / dt +  (L2*K)
            BM[0,10] = Em[0,m1-1] /Z1[0]
            BM[24,10] = (PD2*den*D2*0+z*PD2*den*D2*theta*0)/Z1[24]
            BM[66,10] = (PD3*den*D3*0+z*PD3*den*D3*theta*0)/Z1[66]
            BM[72,10] = (PD4*den*D4*0.45+z*PD4*den*D4*theta*0.45)/Z1[72]
            BM[88,10] = (PD5*den*D5*0.36+z*PD5*den*D5*theta*0.36)/Z1[88]
            BM[148,10] = (PD6*den*D6*0.38+z*PD6*den*D6*theta*0.38)/Z1[148]
            B = BM[:,10]
            RHS[:] = M2.dot(Elag[:,n+1]) + B
            RHS[0] = PD1*den*hb*0.30
            #RHS[M] = -174.73*Elag[M,n]
            Es[:,n+1] = np.linalg.solve(M1, RHS)
            E[:,n+1] = Es[:,n+1] + C[:,n]
            S[0,n+1] = S[0,l1-1]
            S[1:b2,n+1] = E[1:b2,n+1] / (den*PD1*hb+z*den*PD1*hb*theta)
            S[b2:c2,n+1] = E[b2:c2,n+1] / (den*PeriBamGuadD*hb+z*den*PeriBamGuadD*hb*theta)
            S[c2:d2,n+1] = E[c2:d2,n+1] / (den*PeriGuadD*hb+z*den*PeriGuadD*hb*theta)
            S[d2:e2,n+1] = E[d2:e2,n+1] / (den*PeriGuadD*hb+z*den*PeriGuadD*hb*theta)
            S[e2:f2,n+1] = E[e2:f2,n+1] / (den*PeriGuadLamD*hb+z*den*PeriGuadLamD*hb*theta)
            S[f2:g2,n+1] = E[f2:g2,n+1] / (den*PeriLamD*hb+z*den*PeriLamD*hb*theta)
            S[g2:h2,n+1] = E[g2:h2,n+1] / (den*PeriLamD*hb+z*den*PeriLamD*hb*theta)
            Em[0:b2,n+1] = den*PD1*hb*S[0:b2,n+1]
            Em[b2:c2,n+1] = den*PeriBamGuadD*hb*S[b2:c2,n+1]
            Em[c2:d2,n+1] = den*PeriGuadD*hb*S[c2:d2,n+1]
            Em[d2:e2,n+1] = den*PeriGuadD*hb*S[d2:e2,n+1]
            Em[e2:f2,n+1] = den*PeriGuadLamD*hb*S[e2:f2,n+1]
            Em[f2:g2,n+1] = den*PeriLamD*hb*S[f2:g2,n+1]
            Em[g2:h2,n+1] = den*PeriLamD*hb*S[g2:h2,n+1]
            C[:,n+1] = z * S[:,n+1]
            
    return   S, x, t, E

# %%
a2 = 0
b2 = 20
c2 = 58
d2 = 78
e2 = 101
f2 = 147
g2 = 171
h2 = 181

# %%
A1 = np.zeros((M+1,12))
A = np.zeros((M+1))

A1[0:20,0] = 228
A1[20:58,0] = 233
A1[58:78,0] = 238
A1[78:101,0] = 238
A1[101:147,0] = 239
A1[147:171,0] = 241

A1[0:20,1] = 290
A1[20:58,1] = 245
A1[58:78,1] = 200
A1[78:101,1] = 200
A1[101:147,1] = 172
A1[147:171,1] = 145

A1[0:20,2] = 182
A1[20:58,2] = 154
A1[58:78,2] = 126
A1[78:101,2] = 126
A1[101:147,2] = 182
A1[147:171,2] = 238

A1[0:20,3] = 150
A1[20:58,3] = 178
A1[58:78,3] = 207
A1[78:101,3] = 207
A1[101:147,3] = 245
A1[147:171,3] = 283

A1[0:20,4] = 189
A1[20:58,4] = 13
A1[58:78,4] = 84
A1[78:101,4] = 84
A1[101:147,4] = 226
A1[147:171,4] = 368

A1[0:20,5] = 163
A1[20:58,5] = 166
A1[58:78,5] = 169
A1[78:101,5] = 169
A1[101:147,5] = 182
A1[147:171,5] = 196

A1[0:20,6] = 173
A1[20:58,6] = 179
A1[58:78,6] = 185
A1[78:101,6] = 185
A1[101:147,6] = 197
A1[147:171,6] = 209

A1[0:20,7] = 254
A1[20:58,7] = 260
A1[58:78,7] = 266
A1[78:101,7] = 266
A1[101:147,7] = 369
A1[147:171,7] = 473

A1[0:20,8] = 212
A1[20:58,8] = 220
A1[58:78,8] = 228
A1[78:101,8] = 228
A1[101:147,8] = 319
A1[147:171,8] = 411

A1[0:20,9] = 221
A1[20:58,9] = 160
A1[58:78,9] = 99
A1[78:101,9] = 99
A1[101:147,9] = 185
A1[147:171,9] = 272

A1[0:20,10] = 254
A1[20:58,10] = 246
A1[58:78,10] = 238
A1[78:101,10] = 238
A1[101:147,10] = 348
A1[147:171,10] = 459

A1[0:20,11] = 228
A1[20:58,11] = 187
A1[58:78,11] = 147
A1[78:101,11] = 147
A1[101:147,11] = 260
A1[147:171,11] = 374

#January
Jv1 = 1.22
Jv2 = (1.22+0.87)/2
Jv3 = 0.87
Jv4 = 0.87
Jv5 = (0.87+0.1)/2
Jv6 = 0.1

Jk1 = int(Jv1/0.14) 
Jk2 = int(Jv2/0.14) 
Jk3 = int(Jv3/0.14) 
Jk4 = int(Jv4/0.14) 
Jk5 = int(Jv5/0.14) 
Jk6 = int(Jv6/0.14) 

#February
Fv1 = 0.14
Fv2 = (0.14+0.53)/2
Fv3 = 0.53
Fv4 = 0.53
Fv5 = (0.53+2.18)/2
Fv6 = 2.18

Fk1 = int(Fv1/0.14) 
Fk2 = int(Fv2/0.14) 
Fk3 = int(Fv3/0.14) 
Fk4 = int(Fv4/0.14) 
Fk5 = int(Fv5/0.14) 
Fk6 = int(Fv6/0.14) 

#March
Marv1 = 1.21
Marv2 = (1.21+0.11)/2
Marv3 = 0.11
Marv4 = 0.11
Marv5 = (0.11+0.03)/2
Marv6 = 0.03

Mark1 = int(Marv1/0.14) 
Mark2 = int(Marv2/0.14) 
Mark3 = int(Marv3/0.14) 
Mark4 = int(Marv4/0.14) 
Mark5 = int(Marv5/0.14) 
Mark6 = int(Marv6/0.14) 

#April
Apv1 = 0.13
Apv2 = (0.13+0.12)/2
Apv3 = 0.12
Apv4 = 0.12
Apv5 = (0.12+0.12)/2
Apv6 = 0.12

Apk1 = int(Apv1/0.14) 
Apk2 = int(Apv2/0.14) 
Apk3 = int(Apv3/0.14) 
Apk4 = int(Apv4/0.14) 
Apk5 = int(Apv5/0.14) 
Apk6 = int(Apv6/0.14)

#May
Mav1 = 0.35
Mav2 = (0.35+1.04)/2
Mav3 = 1.04
Mav4 = 1.04
Mav5 = (1.04+1.15)/2
Mav6 = 1.15

Mak1 = int(Mav1/0.14) 
Mak2 = int(Mav2/0.14) 
Mak3 = int(Mav3/0.14) 
Mak4 = int(Mav4/0.14) 
Mak5 = int(Mav5/0.14) 
Mak6 = int(Mav6/0.14) 

#June
Junv1 = 0.94
Junv2 = (0.94+1.09)/2
Junv3 = 1.09
Junv4 = 1.09
Junv5 = (1.09+0.12)/2
Junv6 = 0.12

Junk1 = int(Junv1/0.14) 
Junk2 = int(Junv2/0.14) 
Junk3 = int(Junv3/0.14) 
Junk4 = int(Junv4/0.14) 
Junk5 = int(Junv5/0.14) 
Junk6 = int(Junv6/0.14) 

#July
Julv1 = 0.14
Julv2 = (0.14+0.29)/2
Julv3 = 0.29
Julv4 = 0.29
Julv5 = (0.29+0.28)/2
Julv6 = 0.28

Julk1 = int(Julv1/0.14) 
Julk2 = int(Julv2/0.14) 
Julk3 = int(Julv3/0.14) 
Julk4 = int(Julv4/0.14) 
Julk5 = int(Julv5/0.14) 
Julk6 = int(Julv6/0.14) 

#August
Auv1 = 0.22
Auv2 = (0.22+0.15)/2
Auv3 = 0.15
Auv4 = 0.15
Auv5 = (0.15+0.24)/2
Auv6 = 0.24

Auk1 = int(Auv1/0.14) 
Auk2 = int(Auv2/0.14) 
Auk3 = int(Auv3/0.14) 
Auk4 = int(Auv4/0.14) 
Auk5 = int(Auv5/0.14) 
Auk6 = int(Auv6/0.14) 

#September
Sv1 = 0.31
Sv2 = (0.31+0.28)/2
Sv3 = 0.28
Sv4 = 0.28
Sv5 = (0.28+0.26)/2
Sv6 = 0.26

Sk1 = int(Sv1/0.14) 
Sk2 = int(Sv2/0.14) 
Sk3 = int(Sv3/0.14) 
Sk4 = int(Sv4/0.14) 
Sk5 = int(Sv5/0.14) 
Sk6 = int(Sv6/0.14) 

#October
Ov1 = 0.31
Ov2 = (0.31+0.24)/2
Ov3 = 0.24
Ov4 = 0.24
Ov5 = (0.24+1.40)/2
Ov6 = 1.40

Ok1 = int(Ov1/0.14) 
Ok2 = int(Ov2/0.14) 
Ok3 = int(Ov3/0.14) 
Ok4 = int(Ov4/0.14) 
Ok5 = int(Ov5/0.14) 
Ok6 = int(Ov6/0.14) 

#November
Nv1 = 0.12
Nv2 = (0.12+0.95)/2
Nv3 = 0.95
Nv4 = 0.95
Nv5 = (0.95+0.12)/2
Nv6 = 0.12

Nk1 = int(Nv1/0.14) 
Nk2 = int(Nv2/0.14) 
Nk3 = int(Nv3/0.14) 
Nk4 = int(Nv4/0.14) 
Nk5 = int(Nv5/0.14) 
Nk6 = int(Nv6/0.14) 

#December
Dv1 = 0.23
Dv2 = (0.23+0.87)/2
Dv3 = 0.87
Dv4 = 0.87
Dv5 = (0.87+0.14)/2
Dv6 = 0.14

Dk1 = int(Dv1/0.14) 
Dk2 = int(Dv2/0.14) 
Dk3 = int(Dv3/0.14) 
Dk4 = int(Dv4/0.14) 
Dk5 = int(Dv5/0.14) 
Dk6 = int(Dv6/0.14)

# %%
from scipy.integrate import quad
#Solving for matrices L1, L2, L3
T =  31104000
L = 8500
den = 0.01       #density of CIMW and CMW
theta = 1       #porosity
l = 50          #element distance
K = 1000         #dispersion coefficient K=diffusion+dispersitivity*fv
dt = 360        #time step size
dx = 50
N = int(round(T/dt))          #no. of time steps
M = int(round(L/dx))          #no. of nodes

#Solving for A2

def integrand(x):
    return (-1/l)*(-1/l)
ans12, err = quad(integrand, 0, l)

def integrand(x):
    return (-1/l)*(1/l)
ans13, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(-1/l)
ans14, err = quad(integrand, 0, l)

def integrand(x):
    return (1/l)*(1/l)
ans15, err = quad(integrand, 0, l)

L2 = diags([ans14,(ans12+ans15),ans13], [-1,0,1], shape=(M+1, M+1)).toarray()
L2[0,0] = ans12
L2[M,M] = ans15
#L2 is to be multiplied by K and A

#Solving for L3 is zero.

#Solving for M = A1

def integrand(x):
    return (1-x/l)*(1-x/l)
ans20, err = quad(integrand, 0, l)

def integrand(x):
    return (1-x/l)*(x/l)
ans21, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(1-x/l)
ans22, err = quad(integrand, 0, l)

def integrand(x):
    return (x/l)*(x/l)
ans23, err = quad(integrand, 0, l)

Z = diags([ans22,(ans20+ans23),ans21], [-1,0,1], shape=(M+1, M+1)).toarray()
Z[0, 0] = ans20
Z[M, M] = ans23

#A1 Lump Matrix
#Z11 = ans20+ans21
#Z22 = (ans22+ans23+ans20+ans21)*np.ones(M+1)
#Z21 = ans22+ans23
#Z = np.zeros((M+1)**2).reshape(M+1, M+1)+np.diag(Z22, 0)
#Z[0, 0] = Z11
#Z[M, M] = Z21

#solving for QE = L2
#L2[:,:] = L2[:,:]/Z22
#L2[0,:] = L2[0,:]/Z[0, 0]
#L2[M,:] = L2[0,:]/Z[M, M]

U = np.zeros((M+1)**2).reshape(M+1, M+1)+np.diag(np.ones(M+1), 0)


(S,x,t, E) = solver(T,dt, L2, Z)
# Out:
# C:\Users\Cris Lorde\AppData\Local\Temp\ipykernel_14788\110578363.py:119: RuntimeWarning: overflow encountered in multiply
#   Z = np.multiply(Z,A)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], [0.539, 0.42, 0.49, 0.46, 0.40, 0.45, 0.45, 0.37, 0.30, 1.36, 0.30, 0.30], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],[S[0,7200], S[0,14400], S[0,21600], S[0,28800], S[0,36000], S[0,43200], S[0,50400], S[0,57600], S[0,64800], S[0,72000], S[0,79200], S[0,86400]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("MTDS($g/m^3$)")
plt.title("TDS Bambang 2019, $K=1000$")
#plt.savefig('TDS March 2018, K=600, adjusted flow rate.png') 

plt.show()

# %%
plt.plot(S[72,70000:75000])

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug","Sep", "Oct", "Nov", "Dec"], [0.479, 0.48, 0.47, 0.43, 0.49, 0.48, 0.42, 0.32, 0.33, 1.07, 0.29, 0.76], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],[S[72,7200], S[72,14400], S[72,21600], S[72,28800], S[72,36000], S[72,43200], S[72,50400], S[72,57600], S[72,64800], S[72,72000], S[72,79200], S[72,86400]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("TDS($g/m^3$)")
plt.title("TDS Guadalupe 2019")
#plt.savefig('TDS Guadalupe 2019.png') 

plt.show()

# %%
fig, ax = plt.subplots()
#ax.axis([-0.1,9500+0.1,-0.0001,1.1]) 
ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
ax.minorticks_on()


plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], [0.444, 0.39, 0.49, 0.36, 0.55, 0.51, 0.48, 0.31, 0.31, 0.84, 0.32, 0.30], 'ro')
plt.plot(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], [S[170,7200], S[170,14400], S[170,21600], S[170,28800], S[170,36000], S[170,43200], S[170,50400], S[170,57600], S[170,64800], S[170,72000], S[170,79200], S[170,86400]], 'bs')
plt.legend(["actual","simulated"], loc ="upper left")
plt.xlabel("Month")
plt.ylabel("TDS($g/m^3$)")
plt.title("TDS Lambingan 2019")
#plt.savefig('TDS Lambingan 2019.png') 

plt.show()

# %%
plt.plot(S[:,20000])
